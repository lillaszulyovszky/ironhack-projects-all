# %% [markdown]
# ## The Nigerian Funk and Soul Groove Selector

# %%
from IPython.display import display, Image
display(Image(filename='nigerianfunk.jpeg'))

# %% [markdown]
# ### Introduction
#
# People are needlessly suffering the consequences of their own poor taste in music. Wasting their lives listening to other things when they could be living life to the full with Nigerian 70s Funk and Soul as the soundtrack.
#
# ### Our dream
# was to improve world happiness levels by asking for the favourite song of a user and then either <br/>
# a) if their choice is in our top 25 approved Nigerian funk classics, outputting a congratulatory message and recommend another song from that playlist <br/>
# b) if their choice is not in the list, ouputting a recommmended song from another 70s disco and funk playlist on spotify that has some similar attributes to the song they chose.

# %% [markdown]
# ### Our reality

# %% [markdown]
# 1. Got both playlist's ids and audio features through Spotify
# 2. Clustered them
# 3. Added song names to DataFrame
# 4. Did not have time for making the recommendation function to work
# 5. Got a new team member to cheer for us

# %% [markdown]
# ### Our learnings
# 1. Should have listened to Nigerian funk while working
# 2. Ask for help earlier, keep asking
# 3. Practice writing functions

# %% [markdown]
# ### Spotify API

# %%
# import necessary spotipy tools
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import getpass
import pandas as pd

#connecct to api
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="c775f2fba4064b8d89a723f0eb3c4015",
                                                          client_secret="0a1f7dca5ce74bed98f584a787308024"))

# %%
client_id = str(getpass.getpass('client_id?'))
client_secret = str(getpass.getpass('client_secret?'))

# %% [markdown]
# ## Playlists into DataFrames and Clustering

# %% [markdown]
# We will get the audio features of two playlists:

# %%
display(Image(filename='seventies.png'))

# %% [markdown]
# **70s Nigerian funk and soul (named seventiesfunk, 25 songs)**
#
# Playlist link:
# https://open.spotify.com/playlist/5Hnm8iYvXNUEUDXm5cmLBV?si=6b6766865232490a
#
# From that this is the ID: 5Hnm8iYvXNUEUDXm5cmLBV

# %%
display(Image(filename='soultrain.png'))

# %% [markdown]
# **Soul Train 70s Disco and Funk (named soultrain, 875 songs)**
#
# Playlist link:
# https://open.spotify.com/playlist/77VyThCnZyVXifJqBRWrYm
#
# From that this is the ID: 77VyThCnZyVXifJqBRWrYm

# %% [markdown]
# ### Quering the first playlist's audio features

# %%
# get playlist
playlist = sp.user_playlist_tracks("Drew Thomson", "5Hnm8iYvXNUEUDXm5cmLBV")

# %%
# test length
len(playlist['items'])
# Out:
# 25

# %%
# looping through and getting track ids
seventiesfunk = []
for item in playlist['items']:
    seventiesfunk.append(item['track']['id'])

# %%
# track ids of playlist
seventiesfunk
# Out:
# ['05tplGwKpP4IBsxl9YVmqT',
#  '5IxcHoFKH6BUbyxNloo7wA',
#  '4APa6zmDf879PH0pEpCbut',
#  '4QU8y1okxp6BCfsr4jkoTT',
#  '0kvBXRTNvyLRNO3yGh3Gpo',
#  '25MqHSPDiiXWlKa6iQKCpV',
#  '1uJWClfwqs6kpvzPPvLu4n',
#  '6yM82PxMywRHehdoQgQT8p',
#  '3OtnM8u83bnl00TYwF3sWC',
#  '5AarKoTInrX0cN9CsRRFWA',
#  '5mpjIvDq4cgQFyZviKwSRP',
#  '3tGxWRKRtJ7PbZKodKeX38',
#  '4PCW6nxrT9qxet5scL7T1L',
#  '4qjPqmHjPr17SxXD4yTGUR',
#  '7lXMbCKIASfEK0OMOUPaz3',
#  '6RbzqgaaGoKPGXVhD54N5N',
#  '5gw1ST3f229kOxYSs2In15',
#  '72gReM7OIHX7IbHjmg5bY1',
#  '49l7ls7T8hWDFxLo6u9Cxj',
#  '4G0kl0gSf1kLcTmpRj1EAN',
#  '1w95kCIRyAeHcoCRGOH5ma',
#  '2cdWCJGTqyVCaURgMD29rM',
#  '43ile6cBzr9uaC4bJf6J3N',
#  '3DzeFKf8A5Fvt4m848Mnae',
#  '4KQ5vTPl7hTu2fyVcO95XS']

# %%
# these are the audio features for all songs in the playlist
sp.audio_features(tracks=seventiesfunk)
# Out:
# [{'danceability': 0.628,
#   'energy': 0.542,
#   'key': 1,
#   'loudness': -11.973,
#   'mode': 0,
#   'speechiness': 0.32,
#   'acousticness': 0.553,
#   'instrumentalness': 2.58e-05,
#   'liveness': 0.372,
#   'valence': 0.824,
#   'tempo': 107.389,
#   'type': 'audio_features',
#   'id': '05tplGwKpP4IBsxl9YVmqT',
#   'uri': 'spotify:track:05tplGwKpP4IBsxl9YVmqT',
#   'track_href': 'https://api.spotify.com/v1/tracks/05tplGwKpP4IBsxl9YVmqT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05tplGwKpP4IBsxl9YVmqT',
#   'duration_ms': 256301,
#   'time_signature': 4},
#  {'danceability': 0.601,
#   'energy': 0.711,
#   'key': 0,
#   'loudness': -10.698,
#   'mode': 1,
#   'speechiness': 0.106,
#   'acousticness': 0.136,
#   'instrumentalness': 0.00187,
#   'liveness': 0.249,
#   'valence': 0.929,
#   'tempo': 119.385,
#   'type': 'audio_features',
#   'id': '5IxcHoFKH6BUbyxNloo7wA',
#   'uri': 'spotify:track:5IxcHoFKH6BUbyxNloo7wA',
#   'track_href': 'https://api.spotify.com/v1/tracks/5IxcHoFKH6BUbyxNloo7wA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IxcHoFKH6BUbyxNloo7wA',
#   'duration_ms': 292680,
#   'time_signature': 4},
#  {'danceability': 0.725,
#   'energy': 0.655,
#   'key': 1,
#   'loudness': -6.712,
#   'mode': 1,
#   'speechiness': 0.0409,
#   'acousticness': 0.715,
#   'instrumentalness': 0.136,
#   'liveness': 0.283,
#   'valence': 0.74,
#   'tempo': 108.411,
#   'type': 'audio_features',
#   'id': '4APa6zmDf879PH0pEpCbut',
#   'uri': 'spotify:track:4APa6zmDf879PH0pEpCbut',
#   'track_href': 'https://api.spotify.com/v1/tracks/4APa6zmDf879PH0pEpCbut',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4APa6zmDf879PH0pEpCbut',
#   'duration_ms': 204213,
#   'time_signature': 4},
#  {'danceability': 0.68,
#   'energy': 0.748,
#   'key': 1,
#   'loudness': -7.937,
#   'mode': 1,
#   'speechiness': 0.0584,
#   'acousticness': 0.449,
#   'instrumentalness': 0.129,
#   'liveness': 0.0705,
#   'valence': 0.968,
#   'tempo': 108.428,
#   'type': 'audio_features',
#   'id': '4QU8y1okxp6BCfsr4jkoTT',
#   'uri': 'spotify:track:4QU8y1okxp6BCfsr4jkoTT',
#   'track_href': 'https://api.spotify.com/v1/tracks/4QU8y1okxp6BCfsr4jkoTT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4QU8y1okxp6BCfsr4jkoTT',
#   'duration_ms': 498973,
#   'time_signature': 4},
#  {'danceability': 0.703,
#   'energy': 0.699,
#   'key': 5,
#   'loudness': -7.111,
#   'mode': 0,
#   'speechiness': 0.0633,
#   'acousticness': 0.743,
#   'instrumentalness': 0.0469,
#   'liveness': 0.0986,
#   'valence': 0.91,
#   'tempo': 108.687,
#   'type': 'audio_features',
#   'id': '0kvBXRTNvyLRNO3yGh3Gpo',
#   'uri': 'spotify:track:0kvBXRTNvyLRNO3yGh3Gpo',
#   'track_href': 'https://api.spotify.com/v1/tracks/0kvBXRTNvyLRNO3yGh3Gpo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0kvBXRTNvyLRNO3yGh3Gpo',
#   'duration_ms': 330707,
#   'time_signature': 4},
#  {'danceability': 0.727,
#   'energy': 0.732,
#   'key': 1,
#   'loudness': -9.252,
#   'mode': 1,
#   'speechiness': 0.0574,
#   'acousticness': 0.695,
#   'instrumentalness': 0.18,
#   'liveness': 0.104,
#   'valence': 0.856,
#   'tempo': 116.093,
#   'type': 'audio_features',
#   'id': '25MqHSPDiiXWlKa6iQKCpV',
#   'uri': 'spotify:track:25MqHSPDiiXWlKa6iQKCpV',
#   'track_href': 'https://api.spotify.com/v1/tracks/25MqHSPDiiXWlKa6iQKCpV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25MqHSPDiiXWlKa6iQKCpV',
#   'duration_ms': 180294,
#   'time_signature': 4},
#  {'danceability': 0.67,
#   'energy': 0.877,
#   'key': 9,
#   'loudness': -5.907,
#   'mode': 1,
#   'speechiness': 0.0583,
#   'acousticness': 0.605,
#   'instrumentalness': 0.0159,
#   'liveness': 0.119,
#   'valence': 0.734,
#   'tempo': 118.973,
#   'type': 'audio_features',
#   'id': '1uJWClfwqs6kpvzPPvLu4n',
#   'uri': 'spotify:track:1uJWClfwqs6kpvzPPvLu4n',
#   'track_href': 'https://api.spotify.com/v1/tracks/1uJWClfwqs6kpvzPPvLu4n',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1uJWClfwqs6kpvzPPvLu4n',
#   'duration_ms': 307107,
#   'time_signature': 4},
#  {'danceability': 0.718,
#   'energy': 0.626,
#   'key': 10,
#   'loudness': -9.049,
#   'mode': 0,
#   'speechiness': 0.0604,
#   'acousticness': 0.147,
#   'instrumentalness': 0.00207,
#   'liveness': 0.0994,
#   'valence': 0.662,
#   'tempo': 107.288,
#   'type': 'audio_features',
#   'id': '6yM82PxMywRHehdoQgQT8p',
#   'uri': 'spotify:track:6yM82PxMywRHehdoQgQT8p',
#   'track_href': 'https://api.spotify.com/v1/tracks/6yM82PxMywRHehdoQgQT8p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6yM82PxMywRHehdoQgQT8p',
#   'duration_ms': 203040,
#   'time_signature': 4},
#  {'danceability': 0.804,
#   'energy': 0.795,
#   'key': 10,
#   'loudness': -6.645,
#   'mode': 0,
#   'speechiness': 0.0913,
#   'acousticness': 0.118,
#   'instrumentalness': 0.738,
#   'liveness': 0.0593,
#   'valence': 0.858,
#   'tempo': 98.905,
#   'type': 'audio_features',
#   'id': '3OtnM8u83bnl00TYwF3sWC',
#   'uri': 'spotify:track:3OtnM8u83bnl00TYwF3sWC',
#   'track_href': 'https://api.spotify.com/v1/tracks/3OtnM8u83bnl00TYwF3sWC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3OtnM8u83bnl00TYwF3sWC',
#   'duration_ms': 473400,
#   'time_signature': 4},
#  {'danceability': 0.751,
#   'energy': 0.859,
#   'key': 5,
#   'loudness': -6.791,
#   'mode': 0,
#   'speechiness': 0.0446,
#   'acousticness': 0.713,
#   'instrumentalness': 0.265,
#   'liveness': 0.304,
#   'valence': 0.656,
#   'tempo': 123.945,
#   'type': 'audio_features',
#   'id': '5AarKoTInrX0cN9CsRRFWA',
#   'uri': 'spotify:track:5AarKoTInrX0cN9CsRRFWA',
#   'track_href': 'https://api.spotify.com/v1/tracks/5AarKoTInrX0cN9CsRRFWA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5AarKoTInrX0cN9CsRRFWA',
#   'duration_ms': 463702,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.701,
#   'key': 5,
#   'loudness': -10.323,
#   'mode': 0,
#   'speechiness': 0.123,
#   'acousticness': 0.525,
#   'instrumentalness': 0.047,
#   'liveness': 0.235,
#   'valence': 0.884,
#   'tempo': 110.718,
#   'type': 'audio_features',
#   'id': '5mpjIvDq4cgQFyZviKwSRP',
#   'uri': 'spotify:track:5mpjIvDq4cgQFyZviKwSRP',
#   'track_href': 'https://api.spotify.com/v1/tracks/5mpjIvDq4cgQFyZviKwSRP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mpjIvDq4cgQFyZviKwSRP',
#   'duration_ms': 448914,
#   'time_signature': 4},
#  {'danceability': 0.638,
#   'energy': 0.681,
#   'key': 1,
#   'loudness': -7.798,
#   'mode': 1,
#   'speechiness': 0.174,
#   'acousticness': 0.655,
#   'instrumentalness': 0.00177,
#   'liveness': 0.421,
#   'valence': 0.768,
#   'tempo': 161.879,
#   'type': 'audio_features',
#   'id': '3tGxWRKRtJ7PbZKodKeX38',
#   'uri': 'spotify:track:3tGxWRKRtJ7PbZKodKeX38',
#   'track_href': 'https://api.spotify.com/v1/tracks/3tGxWRKRtJ7PbZKodKeX38',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3tGxWRKRtJ7PbZKodKeX38',
#   'duration_ms': 288838,
#   'time_signature': 3},
#  {'danceability': 0.641,
#   'energy': 0.768,
#   'key': 9,
#   'loudness': -7.314,
#   'mode': 0,
#   'speechiness': 0.0521,
#   'acousticness': 0.126,
#   'instrumentalness': 0.558,
#   'liveness': 0.0881,
#   'valence': 0.384,
#   'tempo': 99.512,
#   'type': 'audio_features',
#   'id': '4PCW6nxrT9qxet5scL7T1L',
#   'uri': 'spotify:track:4PCW6nxrT9qxet5scL7T1L',
#   'track_href': 'https://api.spotify.com/v1/tracks/4PCW6nxrT9qxet5scL7T1L',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4PCW6nxrT9qxet5scL7T1L',
#   'duration_ms': 365680,
#   'time_signature': 4},
#  {'danceability': 0.735,
#   'energy': 0.747,
#   'key': 7,
#   'loudness': -7.904,
#   'mode': 0,
#   'speechiness': 0.227,
#   'acousticness': 0.23,
#   'instrumentalness': 0.000335,
#   'liveness': 0.385,
#   'valence': 0.828,
#   'tempo': 134.583,
#   'type': 'audio_features',
#   'id': '4qjPqmHjPr17SxXD4yTGUR',
#   'uri': 'spotify:track:4qjPqmHjPr17SxXD4yTGUR',
#   'track_href': 'https://api.spotify.com/v1/tracks/4qjPqmHjPr17SxXD4yTGUR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4qjPqmHjPr17SxXD4yTGUR',
#   'duration_ms': 401067,
#   'time_signature': 4},
#  {'danceability': 0.68,
#   'energy': 0.559,
#   'key': 0,
#   'loudness': -8.362,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.301,
#   'instrumentalness': 0.177,
#   'liveness': 0.125,
#   'valence': 0.805,
#   'tempo': 134.875,
#   'type': 'audio_features',
#   'id': '7lXMbCKIASfEK0OMOUPaz3',
#   'uri': 'spotify:track:7lXMbCKIASfEK0OMOUPaz3',
#   'track_href': 'https://api.spotify.com/v1/tracks/7lXMbCKIASfEK0OMOUPaz3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7lXMbCKIASfEK0OMOUPaz3',
#   'duration_ms': 179213,
#   'time_signature': 4},
#  {'danceability': 0.742,
#   'energy': 0.882,
#   'key': 5,
#   'loudness': -5.022,
#   'mode': 0,
#   'speechiness': 0.108,
#   'acousticness': 0.456,
#   'instrumentalness': 0.788,
#   'liveness': 0.577,
#   'valence': 0.889,
#   'tempo': 101.942,
#   'type': 'audio_features',
#   'id': '6RbzqgaaGoKPGXVhD54N5N',
#   'uri': 'spotify:track:6RbzqgaaGoKPGXVhD54N5N',
#   'track_href': 'https://api.spotify.com/v1/tracks/6RbzqgaaGoKPGXVhD54N5N',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6RbzqgaaGoKPGXVhD54N5N',
#   'duration_ms': 366107,
#   'time_signature': 4},
#  {'danceability': 0.712,
#   'energy': 0.707,
#   'key': 2,
#   'loudness': -10.829,
#   'mode': 1,
#   'speechiness': 0.0433,
#   'acousticness': 0.428,
#   'instrumentalness': 0.00141,
#   'liveness': 0.735,
#   'valence': 0.782,
#   'tempo': 118.987,
#   'type': 'audio_features',
#   'id': '5gw1ST3f229kOxYSs2In15',
#   'uri': 'spotify:track:5gw1ST3f229kOxYSs2In15',
#   'track_href': 'https://api.spotify.com/v1/tracks/5gw1ST3f229kOxYSs2In15',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5gw1ST3f229kOxYSs2In15',
#   'duration_ms': 244307,
#   'time_signature': 4},
#  {'danceability': 0.676,
#   'energy': 0.746,
#   'key': 0,
#   'loudness': -7.987,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'acousticness': 0.437,
#   'instrumentalness': 0.0407,
#   'liveness': 0.0773,
#   'valence': 0.889,
#   'tempo': 91.953,
#   'type': 'audio_features',
#   'id': '72gReM7OIHX7IbHjmg5bY1',
#   'uri': 'spotify:track:72gReM7OIHX7IbHjmg5bY1',
#   'track_href': 'https://api.spotify.com/v1/tracks/72gReM7OIHX7IbHjmg5bY1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/72gReM7OIHX7IbHjmg5bY1',
#   'duration_ms': 336736,
#   'time_signature': 4},
#  {'danceability': 0.721,
#   'energy': 0.814,
#   'key': 1,
#   'loudness': -8.53,
#   'mode': 0,
#   'speechiness': 0.155,
#   'acousticness': 0.351,
#   'instrumentalness': 0.00346,
#   'liveness': 0.122,
#   'valence': 0.884,
#   'tempo': 118.009,
#   'type': 'audio_features',
#   'id': '49l7ls7T8hWDFxLo6u9Cxj',
#   'uri': 'spotify:track:49l7ls7T8hWDFxLo6u9Cxj',
#   'track_href': 'https://api.spotify.com/v1/tracks/49l7ls7T8hWDFxLo6u9Cxj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/49l7ls7T8hWDFxLo6u9Cxj',
#   'duration_ms': 205454,
#   'time_signature': 4},
#  {'danceability': 0.635,
#   'energy': 0.848,
#   'key': 10,
#   'loudness': -9.387,
#   'mode': 0,
#   'speechiness': 0.058,
#   'acousticness': 0.493,
#   'instrumentalness': 0.00599,
#   'liveness': 0.126,
#   'valence': 0.476,
#   'tempo': 101.753,
#   'type': 'audio_features',
#   'id': '4G0kl0gSf1kLcTmpRj1EAN',
#   'uri': 'spotify:track:4G0kl0gSf1kLcTmpRj1EAN',
#   'track_href': 'https://api.spotify.com/v1/tracks/4G0kl0gSf1kLcTmpRj1EAN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4G0kl0gSf1kLcTmpRj1EAN',
#   'duration_ms': 216047,
#   'time_signature': 4},
#  {'danceability': 0.864,
#   'energy': 0.411,
#   'key': 1,
#   'loudness': -7.684,
#   'mode': 1,
#   'speechiness': 0.226,
#   'acousticness': 0.953,
#   'instrumentalness': 0.135,
#   'liveness': 0.0999,
#   'valence': 0.683,
#   'tempo': 96.839,
#   'type': 'audio_features',
#   'id': '1w95kCIRyAeHcoCRGOH5ma',
#   'uri': 'spotify:track:1w95kCIRyAeHcoCRGOH5ma',
#   'track_href': 'https://api.spotify.com/v1/tracks/1w95kCIRyAeHcoCRGOH5ma',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1w95kCIRyAeHcoCRGOH5ma',
#   'duration_ms': 168373,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.824,
#   'key': 4,
#   'loudness': -5.558,
#   'mode': 0,
#   'speechiness': 0.0382,
#   'acousticness': 0.0482,
#   'instrumentalness': 6.95e-06,
#   'liveness': 0.0217,
#   'valence': 0.859,
#   'tempo': 107.87,
#   'type': 'audio_features',
#   'id': '2cdWCJGTqyVCaURgMD29rM',
#   'uri': 'spotify:track:2cdWCJGTqyVCaURgMD29rM',
#   'track_href': 'https://api.spotify.com/v1/tracks/2cdWCJGTqyVCaURgMD29rM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2cdWCJGTqyVCaURgMD29rM',
#   'duration_ms': 279867,
#   'time_signature': 4},
#  {'danceability': 0.641,
#   'energy': 0.924,
#   'key': 10,
#   'loudness': -7.697,
#   'mode': 0,
#   'speechiness': 0.0578,
#   'acousticness': 0.107,
#   'instrumentalness': 0.0269,
#   'liveness': 0.0982,
#   'valence': 0.891,
#   'tempo': 90.858,
#   'type': 'audio_features',
#   'id': '43ile6cBzr9uaC4bJf6J3N',
#   'uri': 'spotify:track:43ile6cBzr9uaC4bJf6J3N',
#   'track_href': 'https://api.spotify.com/v1/tracks/43ile6cBzr9uaC4bJf6J3N',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43ile6cBzr9uaC4bJf6J3N',
#   'duration_ms': 591707,
#   'time_signature': 4},
#  {'danceability': 0.641,
#   'energy': 0.758,
#   'key': 0,
#   'loudness': -9.799,
#   'mode': 0,
#   'speechiness': 0.0503,
#   'acousticness': 0.627,
#   'instrumentalness': 5.43e-06,
#   'liveness': 0.339,
#   'valence': 0.968,
#   'tempo': 116.159,
#   'type': 'audio_features',
#   'id': '3DzeFKf8A5Fvt4m848Mnae',
#   'uri': 'spotify:track:3DzeFKf8A5Fvt4m848Mnae',
#   'track_href': 'https://api.spotify.com/v1/tracks/3DzeFKf8A5Fvt4m848Mnae',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3DzeFKf8A5Fvt4m848Mnae',
#   'duration_ms': 383773,
#   'time_signature': 4},
#  {'danceability': 0.554,
#   'energy': 0.755,
#   'key': 1,
#   'loudness': -6.596,
#   'mode': 1,
#   'speechiness': 0.0646,
#   'acousticness': 0.254,
#   'instrumentalness': 0.00529,
#   'liveness': 0.091,
#   'valence': 0.849,
#   'tempo': 110.33,
#   'type': 'audio_features',
#   'id': '4KQ5vTPl7hTu2fyVcO95XS',
#   'uri': 'spotify:track:4KQ5vTPl7hTu2fyVcO95XS',
#   'track_href': 'https://api.spotify.com/v1/tracks/4KQ5vTPl7hTu2fyVcO95XS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4KQ5vTPl7hTu2fyVcO95XS',
#   'duration_ms': 173053,
#   'time_signature': 4}]

# %%
# turning list into df
seventiesfunk = pd.DataFrame(sp.audio_features(tracks=seventiesfunk))

# %%
# checking it's shape
seventiesfunk.shape
# Out:
# (25, 18)

# %%
# checking df head
seventiesfunk.head(120)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.628   0.542    1   -11.973     0       0.3200        0.5530
# 1          0.601   0.711    0   -10.698     1       0.1060        0.1360
# 2          0.725   0.655    1    -6.712     1       0.0409        0.7150
# 3          0.680   0.748    1    -7.937     1       0.0584        0.4490
# 4          0.703   0.699    5    -7.111     0       0.0633        0.7430
# 5          0.727   0.732    1    -9.252     1       0.0574        0.6950
# 6          0.670   0.877    9    -5.907     1       0.0583        0.6050
# 7          0.718   0.626   10    -9.049     0       0.0604        0.1470
# 8          0.804   0.795   10    -6.645     0       0.0913        0.1180
# 9          0.751   0.859    5    -6.791     0       0.0446        0.7130
# 10         0.701   0.701    5   -10.323     0       0.1230        0.5250
# 11         0.638   0.681    1    -7.798     1       0.1740        0.6550
# 12         0.641   0.768    9    -7.314     0       0.0521        0.1260
# 13         0.735   0.747    7    -7.904     0       0.2270        0.2300
# 14         0.680   0.559    0    -8.362     1       0.0361        0.3010
# 15         0.742   0.882    5    -5.022     0       0.1080        0.4560
# 16         0.712   0.707    2   -10.829     1       0.0433        0.4280
# 17         0.676   0.746    0    -7.987     1       0.0465        0.4370
# 18         0.721   0.814    1    -8.530     0       0.1550        0.3510
# 19         0.635   0.848   10    -9.387     0       0.0580        0.4930
# 20         0.864   0.411    1    -7.684     1       0.2260        0.9530
# 21         0.687   0.824    4    -5.558     0       0.0382        0.0482
# 22         0.641   0.924   10    -7.697     0       0.0578        0.1070
# 23         0.641   0.758    0    -9.799     0       0.0503        0.6270
# 24         0.554   0.755    1    -6.596     1       0.0646        0.2540
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000026    0.3720    0.824  107.389  audio_features
# 1           0.001870    0.2490    0.929  119.385  audio_features
# 2           0.136000    0.2830    0.740  108.411  audio_features
# 3           0.129000    0.0705    0.968  108.428  audio_features
# 4           0.046900    0.0986    0.910  108.687  audio_features
# 5           0.180000    0.1040    0.856  116.093  audio_features
# 6           0.015900    0.1190    0.734  118.973  audio_features
# 7           0.002070    0.0994    0.662  107.288  audio_features
# 8           0.738000    0.0593    0.858   98.905  audio_features
# 9           0.265000    0.3040    0.656  123.945  audio_features
# 10          0.047000    0.2350    0.884  110.718  audio_features
# 11          0.001770    0.4210    0.768  161.879  audio_features
# 12          0.558000    0.0881    0.384   99.512  audio_features
# 13          0.000335    0.3850    0.828  134.583  audio_features
# 14          0.177000    0.1250    0.805  134.875  audio_features
# 15          0.788000    0.5770    0.889  101.942  audio_features
# 16          0.001410    0.7350    0.782  118.987  audio_features
# 17          0.040700    0.0773    0.889   91.953  audio_features
# 18          0.003460    0.1220    0.884  118.009  audio_features
# 19          0.005990    0.1260    0.476  101.753  audio_features
# 20          0.135000    0.0999    0.683   96.839  audio_features
# 21          0.000007    0.0217    0.859  107.870  audio_features
# 22          0.026900    0.0982    0.891   90.858  audio_features
# 23          0.000005    0.3390    0.968  116.159  audio_features
# 24          0.005290    0.0910    0.849  110.330  audio_features
#
#                         id                                   uri  \
# 0   05tplGwKpP4IBsxl9YVmqT  spotify:track:05tplGwKpP4IBsxl9YVmqT
# 1   5IxcHoFKH6BUbyxNloo7wA  spotify:track:5IxcHoFKH6BUbyxNloo7wA
# 2   4APa6zmDf879PH0pEpCbut  spotify:track:4APa6zmDf879PH0pEpCbut
# 3   4QU8y1okxp6BCfsr4jkoTT  spotify:track:4QU8y1okxp6BCfsr4jkoTT
# 4   0kvBXRTNvyLRNO3yGh3Gpo  spotify:track:0kvBXRTNvyLRNO3yGh3Gpo
# 5   25MqHSPDiiXWlKa6iQKCpV  spotify:track:25MqHSPDiiXWlKa6iQKCpV
# 6   1uJWClfwqs6kpvzPPvLu4n  spotify:track:1uJWClfwqs6kpvzPPvLu4n
# 7   6yM82PxMywRHehdoQgQT8p  spotify:track:6yM82PxMywRHehdoQgQT8p
# 8   3OtnM8u83bnl00TYwF3sWC  spotify:track:3OtnM8u83bnl00TYwF3sWC
# 9   5AarKoTInrX0cN9CsRRFWA  spotify:track:5AarKoTInrX0cN9CsRRFWA
# 10  5mpjIvDq4cgQFyZviKwSRP  spotify:track:5mpjIvDq4cgQFyZviKwSRP
# 11  3tGxWRKRtJ7PbZKodKeX38  spotify:track:3tGxWRKRtJ7PbZKodKeX38
# 12  4PCW6nxrT9qxet5scL7T1L  spotify:track:4PCW6nxrT9qxet5scL7T1L
# 13  4qjPqmHjPr17SxXD4yTGUR  spotify:track:4qjPqmHjPr17SxXD4yTGUR
# 14  7lXMbCKIASfEK0OMOUPaz3  spotify:track:7lXMbCKIASfEK0OMOUPaz3
# 15  6RbzqgaaGoKPGXVhD54N5N  spotify:track:6RbzqgaaGoKPGXVhD54N5N
# 16  5gw1ST3f229kOxYSs2In15  spotify:track:5gw1ST3f229kOxYSs2In15
# 17  72gReM7OIHX7IbHjmg5bY1  spotify:track:72gReM7OIHX7IbHjmg5bY1
# 18  49l7ls7T8hWDFxLo6u9Cxj  spotify:track:49l7ls7T8hWDFxLo6u9Cxj
# 19  4G0kl0gSf1kLcTmpRj1EAN  spotify:track:4G0kl0gSf1kLcTmpRj1EAN
# 20  1w95kCIRyAeHcoCRGOH5ma  spotify:track:1w95kCIRyAeHcoCRGOH5ma
# 21  2cdWCJGTqyVCaURgMD29rM  spotify:track:2cdWCJGTqyVCaURgMD29rM
# 22  43ile6cBzr9uaC4bJf6J3N  spotify:track:43ile6cBzr9uaC4bJf6J3N
# 23  3DzeFKf8A5Fvt4m848Mnae  spotify:track:3DzeFKf8A5Fvt4m848Mnae
# 24  4KQ5vTPl7hTu2fyVcO95XS  spotify:track:4KQ5vTPl7hTu2fyVcO95XS
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/05tplGwKpP4I...
# 1   https://api.spotify.com/v1/tracks/5IxcHoFKH6BU...
# 2   https://api.spotify.com/v1/tracks/4APa6zmDf879...
# 3   https://api.spotify.com/v1/tracks/4QU8y1okxp6B...
# 4   https://api.spotify.com/v1/tracks/0kvBXRTNvyLR...
# 5   https://api.spotify.com/v1/tracks/25MqHSPDiiXW...
# 6   https://api.spotify.com/v1/tracks/1uJWClfwqs6k...
# 7   https://api.spotify.com/v1/tracks/6yM82PxMywRH...
# 8   https://api.spotify.com/v1/tracks/3OtnM8u83bnl...
# 9   https://api.spotify.com/v1/tracks/5AarKoTInrX0...
# 10  https://api.spotify.com/v1/tracks/5mpjIvDq4cgQ...
# 11  https://api.spotify.com/v1/tracks/3tGxWRKRtJ7P...
# 12  https://api.spotify.com/v1/tracks/4PCW6nxrT9qx...
# 13  https://api.spotify.com/v1/tracks/4qjPqmHjPr17...
# 14  https://api.spotify.com/v1/tracks/7lXMbCKIASfE...
# 15  https://api.spotify.com/v1/tracks/6RbzqgaaGoKP...
# 16  https://api.spotify.com/v1/tracks/5gw1ST3f229k...
# 17  https://api.spotify.com/v1/tracks/72gReM7OIHX7...
# 18  https://api.spotify.com/v1/tracks/49l7ls7T8hWD...
# 19  https://api.spotify.com/v1/tracks/4G0kl0gSf1kL...
# 20  https://api.spotify.com/v1/tracks/1w95kCIRyAeH...
# 21  https://api.spotify.com/v1/tracks/2cdWCJGTqyVC...
# 22  https://api.spotify.com/v1/tracks/43ile6cBzr9u...
# 23  https://api.spotify.com/v1/tracks/3DzeFKf8A5Fv...
# 24  https://api.spotify.com/v1/tracks/4KQ5vTPl7hTu...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/05tp...       256301
# 1   https://api.spotify.com/v1/audio-analysis/5Ixc...       292680
# 2   https://api.spotify.com/v1/audio-analysis/4APa...       204213
# 3   https://api.spotify.com/v1/audio-analysis/4QU8...       498973
# 4   https://api.spotify.com/v1/audio-analysis/0kvB...       330707
# 5   https://api.spotify.com/v1/audio-analysis/25Mq...       180294
# 6   https://api.spotify.com/v1/audio-analysis/1uJW...       307107
# 7   https://api.spotify.com/v1/audio-analysis/6yM8...       203040
# 8   https://api.spotify.com/v1/audio-analysis/3Otn...       473400
# 9   https://api.spotify.com/v1/audio-analysis/5Aar...       463702
# 10  https://api.spotify.com/v1/audio-analysis/5mpj...       448914
# 11  https://api.spotify.com/v1/audio-analysis/3tGx...       288838
# 12  https://api.spotify.com/v1/audio-analysis/4PCW...       365680
# 13  https://api.spotify.com/v1/audio-analysis/4qjP...       401067
# 14  https://api.spotify.com/v1/audio-analysis/7lXM...       179213
# 15  https://api.spotify.com/v1/audio-analysis/6Rbz...       366107
# 16  https://api.spotify.com/v1/audio-analysis/5gw1...       244307
# 17  https://api.spotify.com/v1/audio-analysis/72gR...       336736
# 18  https://api.spotify.com/v1/audio-analysis/49l7...       205454
# 19  https://api.spotify.com/v1/audio-analysis/4G0k...       216047
# 20  https://api.spotify.com/v1/audio-analysis/1w95...       168373
# 21  https://api.spotify.com/v1/audio-analysis/2cdW...       279867
# 22  https://api.spotify.com/v1/audio-analysis/43il...       591707
# 23  https://api.spotify.com/v1/audio-analysis/3Dze...       383773
# 24  https://api.spotify.com/v1/audio-analysis/4KQ5...       173053
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                4
# 10               4
# 11               3
# 12               4
# 13               4
# 14               4
# 15               4
# 16               4
# 17               4
# 18               4
# 19               4
# 20               4
# 21               4
# 22               4
# 23               4
# 24               4

# %% [markdown]
# ### Dropping columns, preparing for scaling

# %%
seventiesfunk = seventiesfunk.drop(['type', 'id', 'uri', 'track_href', 'analysis_url'],  axis=1)

# %%
X_sf = seventiesfunk

# %% [markdown]
# ### Applying StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
X_prep_sf = StandardScaler().fit_transform(X_sf)

X_prep_sf_df = pd.DataFrame(X_prep_sf, columns = seventiesfunk.columns)

# %% [markdown]
# ### Preparing the clusters

# %%
from sklearn.cluster import KMeans

kmeans_sf = KMeans(n_clusters=8, random_state=1234)

kmeans_sf.fit(X_prep_sf_df)

kmeans_sf.cluster_centers_
# Out:
# array([[-0.41469456,  0.11043345,  1.53183788, -0.27616101, -0.88640526,
#         -0.52707234, -0.74387921,  0.25410258, -0.61670935, -2.10967081,
#         -0.6485443 , -0.4599714 ,  0.20412415],
#        [-0.36023309, -0.14940135, -0.59322927, -0.10503329,  1.12815215,
#         -0.52981849,  0.04882579, -0.28107271,  0.06260317,  0.17328268,
#          0.15545496, -0.65068075,  0.20412415],
#        [ 0.21372143,  0.22921508, -0.14265112, -0.13406016, -0.59861134,
#          0.12151805,  0.35313855, -0.27894998,  0.05745027,  0.52145978,
#          0.31208123,  0.66206074,  0.20412415],
#        [-0.83463842, -0.47218205, -0.79455142,  0.18652946,  1.12815215,
#          1.11593873,  0.91449076, -0.58711031,  1.19899771, -0.22448641,
#          3.29814688, -0.22255864, -4.89897949],
#        [ 1.29132737,  0.9111638 ,  0.95024056,  1.34394299, -0.88640526,
#          0.07333953, -0.61248209,  2.83878262,  0.60896462,  0.53850702,
#         -0.8108502 ,  0.9180708 ,  0.20412415],
#        [ 2.7243858 , -2.84363209, -0.79455142,  0.25369421,  1.12815215,
#          1.84512714,  2.15100682,  0.01248733, -0.64309877, -0.83922045,
#         -1.05051468, -1.27213584,  0.20412415],
#        [-0.42519316,  1.22296557,  0.81602579,  0.87614643, -0.88640526,
#         -0.65094089, -1.48136283, -0.53452918, -0.87228517,  0.54935527,
#         -0.88168979,  1.05776611,  0.20412415],
#        [-0.99211737, -1.69303966, -0.79455142, -2.27323206, -0.88640526,
#          3.16327543,  0.49125372, -0.59496003,  0.91789298,  0.18051484,
#         -0.34512754, -0.50604424,  0.20412415]])

# %%
# total inertia of all the centroids
kmeans_sf.inertia_
# Out:
# 116.99424728589669

# %%
clusters_sf = kmeans_sf.predict(X_prep_sf)
clusters_sf
# Out:
# array([7, 1, 1, 2, 2, 1, 1, 0, 4, 2, 2, 3, 0, 2, 1, 4, 1, 1, 2, 0, 5, 6,
#        6, 2, 1], dtype=int32)

# %%
pd.Series(clusters_sf).value_counts().sort_index()
# Out:
# 0    3
# 1    8
# 2    7
# 3    1
# 4    2
# 5    1
# 6    2
# 7    1
# dtype: int64

# %%
kmeans_sf.cluster_centers_
# Out:
# array([[-0.41469456,  0.11043345,  1.53183788, -0.27616101, -0.88640526,
#         -0.52707234, -0.74387921,  0.25410258, -0.61670935, -2.10967081,
#         -0.6485443 , -0.4599714 ,  0.20412415],
#        [-0.36023309, -0.14940135, -0.59322927, -0.10503329,  1.12815215,
#         -0.52981849,  0.04882579, -0.28107271,  0.06260317,  0.17328268,
#          0.15545496, -0.65068075,  0.20412415],
#        [ 0.21372143,  0.22921508, -0.14265112, -0.13406016, -0.59861134,
#          0.12151805,  0.35313855, -0.27894998,  0.05745027,  0.52145978,
#          0.31208123,  0.66206074,  0.20412415],
#        [-0.83463842, -0.47218205, -0.79455142,  0.18652946,  1.12815215,
#          1.11593873,  0.91449076, -0.58711031,  1.19899771, -0.22448641,
#          3.29814688, -0.22255864, -4.89897949],
#        [ 1.29132737,  0.9111638 ,  0.95024056,  1.34394299, -0.88640526,
#          0.07333953, -0.61248209,  2.83878262,  0.60896462,  0.53850702,
#         -0.8108502 ,  0.9180708 ,  0.20412415],
#        [ 2.7243858 , -2.84363209, -0.79455142,  0.25369421,  1.12815215,
#          1.84512714,  2.15100682,  0.01248733, -0.64309877, -0.83922045,
#         -1.05051468, -1.27213584,  0.20412415],
#        [-0.42519316,  1.22296557,  0.81602579,  0.87614643, -0.88640526,
#         -0.65094089, -1.48136283, -0.53452918, -0.87228517,  0.54935527,
#         -0.88168979,  1.05776611,  0.20412415],
#        [-0.99211737, -1.69303966, -0.79455142, -2.27323206, -0.88640526,
#          3.16327543,  0.49125372, -0.59496003,  0.91789298,  0.18051484,
#         -0.34512754, -0.50604424,  0.20412415]])

# %%
X_sf_df = pd.DataFrame(X_sf)
X_sf_df['cluster'] = clusters_sf
X_sf_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.628   0.542    1   -11.973     0       0.3200         0.553
# 1         0.601   0.711    0   -10.698     1       0.1060         0.136
# 2         0.725   0.655    1    -6.712     1       0.0409         0.715
# 3         0.680   0.748    1    -7.937     1       0.0584         0.449
# 4         0.703   0.699    5    -7.111     0       0.0633         0.743
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.000026    0.3720    0.824  107.389       256301               4
# 1          0.001870    0.2490    0.929  119.385       292680               4
# 2          0.136000    0.2830    0.740  108.411       204213               4
# 3          0.129000    0.0705    0.968  108.428       498973               4
# 4          0.046900    0.0986    0.910  108.687       330707               4
#
#    cluster
# 0        7
# 1        1
# 2        1
# 3        2
# 4        2

# %%
X_sf_df['cluster'].plot(kind='hist');

# %% [markdown]
# ## Quering the second playlist's audio features

# %%
# getting playlist
playlist = sp.user_playlist_tracks("djlarras", "77VyThCnZyVXifJqBRWrYm")

# %% [markdown]
# ### Function to get all 850 songs instead of 100

# %%
#set variables
playlist_id = "77VyThCnZyVXifJqBRWrYm"
#1- define function
def get_playlist_tracks(playlist_id):
    results= sp.playlist_tracks(playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
#2- call function on playlist
full_track_ids= get_playlist_tracks(playlist_id)

# %%
soultrain = get_playlist_tracks(playlist_id)

# %%
# get track ids
soultrain_1 = []
for item in soultrain:
    soultrain_1.append(item['track']['id'])

# %%
#check length
len(soultrain_1)
# Out:
# 875

# %%
# these are the audio features for all songs in the playlist
sp.audio_features(tracks=soultrain_1[:50])
# Out:
# [{'danceability': 0.754,
#   'energy': 0.673,
#   'key': 7,
#   'loudness': -10.211,
#   'mode': 0,
#   'speechiness': 0.0299,
#   'acousticness': 0.127,
#   'instrumentalness': 0.000681,
#   'liveness': 0.129,
#   'valence': 0.967,
#   'tempo': 112.669,
#   'type': 'audio_features',
#   'id': '2wNKo4dQkKV06ebyb34Ffb',
#   'uri': 'spotify:track:2wNKo4dQkKV06ebyb34Ffb',
#   'track_href': 'https://api.spotify.com/v1/tracks/2wNKo4dQkKV06ebyb34Ffb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2wNKo4dQkKV06ebyb34Ffb',
#   'duration_ms': 260693,
#   'time_signature': 4},
#  {'danceability': 0.869,
#   'energy': 0.648,
#   'key': 11,
#   'loudness': -8.698,
#   'mode': 0,
#   'speechiness': 0.0633,
#   'acousticness': 0.121,
#   'instrumentalness': 2.17e-05,
#   'liveness': 0.126,
#   'valence': 0.9,
#   'tempo': 125.035,
#   'type': 'audio_features',
#   'id': '3koCCeSaVUyrRo3N2gHrd8',
#   'uri': 'spotify:track:3koCCeSaVUyrRo3N2gHrd8',
#   'track_href': 'https://api.spotify.com/v1/tracks/3koCCeSaVUyrRo3N2gHrd8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3koCCeSaVUyrRo3N2gHrd8',
#   'duration_ms': 339320,
#   'time_signature': 4},
#  {'danceability': 0.802,
#   'energy': 0.756,
#   'key': 2,
#   'loudness': -10.791,
#   'mode': 0,
#   'speechiness': 0.0349,
#   'acousticness': 0.0843,
#   'instrumentalness': 0.00765,
#   'liveness': 0.0521,
#   'valence': 0.963,
#   'tempo': 131.715,
#   'type': 'audio_features',
#   'id': '6ztstiyZL6FXzh4aG46ZPD',
#   'uri': 'spotify:track:6ztstiyZL6FXzh4aG46ZPD',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ztstiyZL6FXzh4aG46ZPD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ztstiyZL6FXzh4aG46ZPD',
#   'duration_ms': 288293,
#   'time_signature': 4},
#  {'danceability': 0.611,
#   'energy': 0.899,
#   'key': 2,
#   'loudness': -10.897,
#   'mode': 1,
#   'speechiness': 0.032,
#   'acousticness': 0.0141,
#   'instrumentalness': 0.0966,
#   'liveness': 0.0786,
#   'valence': 0.847,
#   'tempo': 100.868,
#   'type': 'audio_features',
#   'id': '60z6SdowBWlN6n8U0O2NP8',
#   'uri': 'spotify:track:60z6SdowBWlN6n8U0O2NP8',
#   'track_href': 'https://api.spotify.com/v1/tracks/60z6SdowBWlN6n8U0O2NP8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60z6SdowBWlN6n8U0O2NP8',
#   'duration_ms': 549000,
#   'time_signature': 4},
#  {'danceability': 0.817,
#   'energy': 0.754,
#   'key': 11,
#   'loudness': -8.347,
#   'mode': 1,
#   'speechiness': 0.0467,
#   'acousticness': 0.174,
#   'instrumentalness': 0.0138,
#   'liveness': 0.0597,
#   'valence': 0.924,
#   'tempo': 98.182,
#   'type': 'audio_features',
#   'id': '2rZFZPfEf54mWk2qGkR2SV',
#   'uri': 'spotify:track:2rZFZPfEf54mWk2qGkR2SV',
#   'track_href': 'https://api.spotify.com/v1/tracks/2rZFZPfEf54mWk2qGkR2SV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2rZFZPfEf54mWk2qGkR2SV',
#   'duration_ms': 244440,
#   'time_signature': 4},
#  {'danceability': 0.718,
#   'energy': 0.676,
#   'key': 11,
#   'loudness': -11.633,
#   'mode': 0,
#   'speechiness': 0.0318,
#   'acousticness': 0.153,
#   'instrumentalness': 0.0306,
#   'liveness': 0.0706,
#   'valence': 0.944,
#   'tempo': 112.711,
#   'type': 'audio_features',
#   'id': '1uGFGhxJ9ISGcy7iDffP7V',
#   'uri': 'spotify:track:1uGFGhxJ9ISGcy7iDffP7V',
#   'track_href': 'https://api.spotify.com/v1/tracks/1uGFGhxJ9ISGcy7iDffP7V',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1uGFGhxJ9ISGcy7iDffP7V',
#   'duration_ms': 316267,
#   'time_signature': 4},
#  {'danceability': 0.667,
#   'energy': 0.577,
#   'key': 11,
#   'loudness': -12.729,
#   'mode': 1,
#   'speechiness': 0.163,
#   'acousticness': 0.228,
#   'instrumentalness': 3.94e-05,
#   'liveness': 0.0566,
#   'valence': 0.923,
#   'tempo': 111.802,
#   'type': 'audio_features',
#   'id': '5F8CrWvnESlOBmFkyxFJqt',
#   'uri': 'spotify:track:5F8CrWvnESlOBmFkyxFJqt',
#   'track_href': 'https://api.spotify.com/v1/tracks/5F8CrWvnESlOBmFkyxFJqt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5F8CrWvnESlOBmFkyxFJqt',
#   'duration_ms': 209800,
#   'time_signature': 4},
#  {'danceability': 0.673,
#   'energy': 0.752,
#   'key': 9,
#   'loudness': -7.978,
#   'mode': 0,
#   'speechiness': 0.0491,
#   'acousticness': 0.00309,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'valence': 0.576,
#   'tempo': 120.041,
#   'type': 'audio_features',
#   'id': '2a1MrtxYybqFV1Ow8VJ1dW',
#   'uri': 'spotify:track:2a1MrtxYybqFV1Ow8VJ1dW',
#   'track_href': 'https://api.spotify.com/v1/tracks/2a1MrtxYybqFV1Ow8VJ1dW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2a1MrtxYybqFV1Ow8VJ1dW',
#   'duration_ms': 265027,
#   'time_signature': 4},
#  {'danceability': 0.774,
#   'energy': 0.641,
#   'key': 1,
#   'loudness': -10.193,
#   'mode': 1,
#   'speechiness': 0.0799,
#   'acousticness': 0.0765,
#   'instrumentalness': 0,
#   'liveness': 0.0867,
#   'valence': 0.875,
#   'tempo': 113.256,
#   'type': 'audio_features',
#   'id': '3qI94hINNNeb4S7xQi18lS',
#   'uri': 'spotify:track:3qI94hINNNeb4S7xQi18lS',
#   'track_href': 'https://api.spotify.com/v1/tracks/3qI94hINNNeb4S7xQi18lS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3qI94hINNNeb4S7xQi18lS',
#   'duration_ms': 214200,
#   'time_signature': 4},
#  {'danceability': 0.879,
#   'energy': 0.626,
#   'key': 7,
#   'loudness': -6.344,
#   'mode': 1,
#   'speechiness': 0.0604,
#   'acousticness': 0.205,
#   'instrumentalness': 6.07e-05,
#   'liveness': 0.056,
#   'valence': 0.968,
#   'tempo': 110.864,
#   'type': 'audio_features',
#   'id': '1OsCKwNZxph96EkNusILRy',
#   'uri': 'spotify:track:1OsCKwNZxph96EkNusILRy',
#   'track_href': 'https://api.spotify.com/v1/tracks/1OsCKwNZxph96EkNusILRy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1OsCKwNZxph96EkNusILRy',
#   'duration_ms': 212907,
#   'time_signature': 4},
#  {'danceability': 0.843,
#   'energy': 0.656,
#   'key': 1,
#   'loudness': -11.184,
#   'mode': 1,
#   'speechiness': 0.0595,
#   'acousticness': 0.0466,
#   'instrumentalness': 0.0187,
#   'liveness': 0.169,
#   'valence': 0.931,
#   'tempo': 121.112,
#   'type': 'audio_features',
#   'id': '6pc8xULSlsMdFB3OrqbvZ4',
#   'uri': 'spotify:track:6pc8xULSlsMdFB3OrqbvZ4',
#   'track_href': 'https://api.spotify.com/v1/tracks/6pc8xULSlsMdFB3OrqbvZ4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6pc8xULSlsMdFB3OrqbvZ4',
#   'duration_ms': 215653,
#   'time_signature': 4},
#  {'danceability': 0.668,
#   'energy': 0.916,
#   'key': 9,
#   'loudness': -7.59,
#   'mode': 0,
#   'speechiness': 0.0495,
#   'acousticness': 0.0164,
#   'instrumentalness': 0.256,
#   'liveness': 0.05,
#   'valence': 0.922,
#   'tempo': 115.784,
#   'type': 'audio_features',
#   'id': '1WKDC0p94KNWNzCpxxUs8w',
#   'uri': 'spotify:track:1WKDC0p94KNWNzCpxxUs8w',
#   'track_href': 'https://api.spotify.com/v1/tracks/1WKDC0p94KNWNzCpxxUs8w',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1WKDC0p94KNWNzCpxxUs8w',
#   'duration_ms': 311907,
#   'time_signature': 4},
#  {'danceability': 0.827,
#   'energy': 0.578,
#   'key': 6,
#   'loudness': -12.871,
#   'mode': 0,
#   'speechiness': 0.0483,
#   'acousticness': 0.206,
#   'instrumentalness': 0.0314,
#   'liveness': 0.0925,
#   'valence': 0.968,
#   'tempo': 111.447,
#   'type': 'audio_features',
#   'id': '6EOAOGls9pIdUJsrqytcXK',
#   'uri': 'spotify:track:6EOAOGls9pIdUJsrqytcXK',
#   'track_href': 'https://api.spotify.com/v1/tracks/6EOAOGls9pIdUJsrqytcXK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6EOAOGls9pIdUJsrqytcXK',
#   'duration_ms': 269640,
#   'time_signature': 4},
#  {'danceability': 0.865,
#   'energy': 0.556,
#   'key': 4,
#   'loudness': -13.372,
#   'mode': 0,
#   'speechiness': 0.0555,
#   'acousticness': 0.0137,
#   'instrumentalness': 0.0145,
#   'liveness': 0.07,
#   'valence': 0.887,
#   'tempo': 118.946,
#   'type': 'audio_features',
#   'id': '35rKsWYxrPqXhqiZ8KssQC',
#   'uri': 'spotify:track:35rKsWYxrPqXhqiZ8KssQC',
#   'track_href': 'https://api.spotify.com/v1/tracks/35rKsWYxrPqXhqiZ8KssQC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/35rKsWYxrPqXhqiZ8KssQC',
#   'duration_ms': 464227,
#   'time_signature': 4},
#  {'danceability': 0.77,
#   'energy': 0.827,
#   'key': 1,
#   'loudness': -8.754,
#   'mode': 1,
#   'speechiness': 0.0369,
#   'acousticness': 0.298,
#   'instrumentalness': 0.000357,
#   'liveness': 0.199,
#   'valence': 0.888,
#   'tempo': 109.058,
#   'type': 'audio_features',
#   'id': '5QVdcoYVUHU143cTfgmULG',
#   'uri': 'spotify:track:5QVdcoYVUHU143cTfgmULG',
#   'track_href': 'https://api.spotify.com/v1/tracks/5QVdcoYVUHU143cTfgmULG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5QVdcoYVUHU143cTfgmULG',
#   'duration_ms': 211253,
#   'time_signature': 4},
#  {'danceability': 0.77,
#   'energy': 0.547,
#   'key': 8,
#   'loudness': -10.592,
#   'mode': 1,
#   'speechiness': 0.044,
#   'acousticness': 0.28,
#   'instrumentalness': 3.56e-05,
#   'liveness': 0.164,
#   'valence': 0.841,
#   'tempo': 112.351,
#   'type': 'audio_features',
#   'id': '4QlnPFkUTynVPpfr6IfK2m',
#   'uri': 'spotify:track:4QlnPFkUTynVPpfr6IfK2m',
#   'track_href': 'https://api.spotify.com/v1/tracks/4QlnPFkUTynVPpfr6IfK2m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4QlnPFkUTynVPpfr6IfK2m',
#   'duration_ms': 220404,
#   'time_signature': 4},
#  {'danceability': 0.846,
#   'energy': 0.7,
#   'key': 6,
#   'loudness': -4.984,
#   'mode': 0,
#   'speechiness': 0.0498,
#   'acousticness': 0.0455,
#   'instrumentalness': 0.000668,
#   'liveness': 0.322,
#   'valence': 0.877,
#   'tempo': 125.477,
#   'type': 'audio_features',
#   'id': '6PZDXTlPfO7nBN1Cd7c3zv',
#   'uri': 'spotify:track:6PZDXTlPfO7nBN1Cd7c3zv',
#   'track_href': 'https://api.spotify.com/v1/tracks/6PZDXTlPfO7nBN1Cd7c3zv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6PZDXTlPfO7nBN1Cd7c3zv',
#   'duration_ms': 230307,
#   'time_signature': 4},
#  {'danceability': 0.656,
#   'energy': 0.9,
#   'key': 5,
#   'loudness': -9.583,
#   'mode': 0,
#   'speechiness': 0.0354,
#   'acousticness': 0.0791,
#   'instrumentalness': 0.00142,
#   'liveness': 0.354,
#   'valence': 0.947,
#   'tempo': 108.698,
#   'type': 'audio_features',
#   'id': '3P2zU7fEjnZRunH124QnJL',
#   'uri': 'spotify:track:3P2zU7fEjnZRunH124QnJL',
#   'track_href': 'https://api.spotify.com/v1/tracks/3P2zU7fEjnZRunH124QnJL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3P2zU7fEjnZRunH124QnJL',
#   'duration_ms': 183667,
#   'time_signature': 4},
#  {'danceability': 0.85,
#   'energy': 0.769,
#   'key': 4,
#   'loudness': -8.648,
#   'mode': 0,
#   'speechiness': 0.0359,
#   'acousticness': 0.0289,
#   'instrumentalness': 0.01,
#   'liveness': 0.0899,
#   'valence': 0.967,
#   'tempo': 122.007,
#   'type': 'audio_features',
#   'id': '2xGMzDlPnmPHD8HUYOy4Lw',
#   'uri': 'spotify:track:2xGMzDlPnmPHD8HUYOy4Lw',
#   'track_href': 'https://api.spotify.com/v1/tracks/2xGMzDlPnmPHD8HUYOy4Lw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2xGMzDlPnmPHD8HUYOy4Lw',
#   'duration_ms': 184453,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.834,
#   'key': 10,
#   'loudness': -7.131,
#   'mode': 0,
#   'speechiness': 0.0358,
#   'acousticness': 0.0291,
#   'instrumentalness': 0.00492,
#   'liveness': 0.147,
#   'valence': 0.923,
#   'tempo': 103.555,
#   'type': 'audio_features',
#   'id': '5cP52DlDN9yryuZVQDg3iq',
#   'uri': 'spotify:track:5cP52DlDN9yryuZVQDg3iq',
#   'track_href': 'https://api.spotify.com/v1/tracks/5cP52DlDN9yryuZVQDg3iq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5cP52DlDN9yryuZVQDg3iq',
#   'duration_ms': 285373,
#   'time_signature': 4},
#  {'danceability': 0.729,
#   'energy': 0.794,
#   'key': 1,
#   'loudness': -7.208,
#   'mode': 0,
#   'speechiness': 0.0249,
#   'acousticness': 0.0245,
#   'instrumentalness': 0.00125,
#   'liveness': 0.0897,
#   'valence': 0.896,
#   'tempo': 109.123,
#   'type': 'audio_features',
#   'id': '66wpCqkkM6MrxXSbfgmsrh',
#   'uri': 'spotify:track:66wpCqkkM6MrxXSbfgmsrh',
#   'track_href': 'https://api.spotify.com/v1/tracks/66wpCqkkM6MrxXSbfgmsrh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/66wpCqkkM6MrxXSbfgmsrh',
#   'duration_ms': 213400,
#   'time_signature': 4},
#  {'danceability': 0.676,
#   'energy': 0.704,
#   'key': 10,
#   'loudness': -8.534,
#   'mode': 1,
#   'speechiness': 0.0329,
#   'acousticness': 0.000362,
#   'instrumentalness': 0.0709,
#   'liveness': 0.139,
#   'valence': 0.812,
#   'tempo': 129.594,
#   'type': 'audio_features',
#   'id': '3GXo1eWlT2flv4x01l5OTu',
#   'uri': 'spotify:track:3GXo1eWlT2flv4x01l5OTu',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GXo1eWlT2flv4x01l5OTu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GXo1eWlT2flv4x01l5OTu',
#   'duration_ms': 213840,
#   'time_signature': 4},
#  {'danceability': 0.797,
#   'energy': 0.738,
#   'key': 0,
#   'loudness': -13.87,
#   'mode': 1,
#   'speechiness': 0.0341,
#   'acousticness': 0.00254,
#   'instrumentalness': 0.132,
#   'liveness': 0.0433,
#   'valence': 0.964,
#   'tempo': 120.494,
#   'type': 'audio_features',
#   'id': '6RVevoPzbGygqvm6LxHAuf',
#   'uri': 'spotify:track:6RVevoPzbGygqvm6LxHAuf',
#   'track_href': 'https://api.spotify.com/v1/tracks/6RVevoPzbGygqvm6LxHAuf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6RVevoPzbGygqvm6LxHAuf',
#   'duration_ms': 400440,
#   'time_signature': 4},
#  {'danceability': 0.69,
#   'energy': 0.675,
#   'key': 0,
#   'loudness': -16.247,
#   'mode': 1,
#   'speechiness': 0.0433,
#   'acousticness': 0.0127,
#   'instrumentalness': 0.648,
#   'liveness': 0.0987,
#   'valence': 0.94,
#   'tempo': 128.1,
#   'type': 'audio_features',
#   'id': '6efRrfjV1YW1rtecLUHoP1',
#   'uri': 'spotify:track:6efRrfjV1YW1rtecLUHoP1',
#   'track_href': 'https://api.spotify.com/v1/tracks/6efRrfjV1YW1rtecLUHoP1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6efRrfjV1YW1rtecLUHoP1',
#   'duration_ms': 493600,
#   'time_signature': 4},
#  {'danceability': 0.857,
#   'energy': 0.7,
#   'key': 2,
#   'loudness': -14.506,
#   'mode': 0,
#   'speechiness': 0.0358,
#   'acousticness': 0.00387,
#   'instrumentalness': 0.0164,
#   'liveness': 0.411,
#   'valence': 0.973,
#   'tempo': 120.529,
#   'type': 'audio_features',
#   'id': '3ZKQVyxT4Jg2lLZRLs7Vgo',
#   'uri': 'spotify:track:3ZKQVyxT4Jg2lLZRLs7Vgo',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZKQVyxT4Jg2lLZRLs7Vgo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZKQVyxT4Jg2lLZRLs7Vgo',
#   'duration_ms': 295107,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.493,
#   'key': 4,
#   'loudness': -11.753,
#   'mode': 0,
#   'speechiness': 0.0372,
#   'acousticness': 0.111,
#   'instrumentalness': 4.73e-06,
#   'liveness': 0.112,
#   'valence': 0.63,
#   'tempo': 128.2,
#   'type': 'audio_features',
#   'id': '7ILc1RLXuw9BymDfgHAJIP',
#   'uri': 'spotify:track:7ILc1RLXuw9BymDfgHAJIP',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ILc1RLXuw9BymDfgHAJIP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ILc1RLXuw9BymDfgHAJIP',
#   'duration_ms': 244667,
#   'time_signature': 4},
#  {'danceability': 0.665,
#   'energy': 0.559,
#   'key': 7,
#   'loudness': -13.754,
#   'mode': 0,
#   'speechiness': 0.0443,
#   'acousticness': 0.0571,
#   'instrumentalness': 0.000309,
#   'liveness': 0.0702,
#   'valence': 0.4,
#   'tempo': 135.177,
#   'type': 'audio_features',
#   'id': '5p8dIMGzLeRL6KcyvMD7D0',
#   'uri': 'spotify:track:5p8dIMGzLeRL6KcyvMD7D0',
#   'track_href': 'https://api.spotify.com/v1/tracks/5p8dIMGzLeRL6KcyvMD7D0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5p8dIMGzLeRL6KcyvMD7D0',
#   'duration_ms': 702960,
#   'time_signature': 4},
#  {'danceability': 0.836,
#   'energy': 0.549,
#   'key': 5,
#   'loudness': -9.03,
#   'mode': 0,
#   'speechiness': 0.0516,
#   'acousticness': 0.0368,
#   'instrumentalness': 0.0603,
#   'liveness': 0.0352,
#   'valence': 0.965,
#   'tempo': 125.176,
#   'type': 'audio_features',
#   'id': '4OxvkxxkLFUjRLzQJUr7lz',
#   'uri': 'spotify:track:4OxvkxxkLFUjRLzQJUr7lz',
#   'track_href': 'https://api.spotify.com/v1/tracks/4OxvkxxkLFUjRLzQJUr7lz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4OxvkxxkLFUjRLzQJUr7lz',
#   'duration_ms': 230200,
#   'time_signature': 4},
#  {'danceability': 0.778,
#   'energy': 0.818,
#   'key': 5,
#   'loudness': -9.526,
#   'mode': 0,
#   'speechiness': 0.0461,
#   'acousticness': 0.18,
#   'instrumentalness': 0.000644,
#   'liveness': 0.0647,
#   'valence': 0.921,
#   'tempo': 119.039,
#   'type': 'audio_features',
#   'id': '2MKsIrTocRAHcYnl6SKD4r',
#   'uri': 'spotify:track:2MKsIrTocRAHcYnl6SKD4r',
#   'track_href': 'https://api.spotify.com/v1/tracks/2MKsIrTocRAHcYnl6SKD4r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MKsIrTocRAHcYnl6SKD4r',
#   'duration_ms': 320040,
#   'time_signature': 4},
#  {'danceability': 0.839,
#   'energy': 0.526,
#   'key': 11,
#   'loudness': -12.579,
#   'mode': 0,
#   'speechiness': 0.0478,
#   'acousticness': 0.0261,
#   'instrumentalness': 0.00552,
#   'liveness': 0.162,
#   'valence': 0.711,
#   'tempo': 96.203,
#   'type': 'audio_features',
#   'id': '7KFoa0H8CVO6VxLK31aehG',
#   'uri': 'spotify:track:7KFoa0H8CVO6VxLK31aehG',
#   'track_href': 'https://api.spotify.com/v1/tracks/7KFoa0H8CVO6VxLK31aehG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7KFoa0H8CVO6VxLK31aehG',
#   'duration_ms': 335064,
#   'time_signature': 4},
#  {'danceability': 0.8,
#   'energy': 0.77,
#   'key': 1,
#   'loudness': -11.271,
#   'mode': 0,
#   'speechiness': 0.0415,
#   'acousticness': 0.0176,
#   'instrumentalness': 0.0115,
#   'liveness': 0.0285,
#   'valence': 0.96,
#   'tempo': 118.832,
#   'type': 'audio_features',
#   'id': '69IFOdcqRAceXkikTCblWA',
#   'uri': 'spotify:track:69IFOdcqRAceXkikTCblWA',
#   'track_href': 'https://api.spotify.com/v1/tracks/69IFOdcqRAceXkikTCblWA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/69IFOdcqRAceXkikTCblWA',
#   'duration_ms': 312800,
#   'time_signature': 4},
#  {'danceability': 0.814,
#   'energy': 0.645,
#   'key': 2,
#   'loudness': -8.912,
#   'mode': 0,
#   'speechiness': 0.0377,
#   'acousticness': 0.0924,
#   'instrumentalness': 0.00398,
#   'liveness': 0.3,
#   'valence': 0.96,
#   'tempo': 112.757,
#   'type': 'audio_features',
#   'id': '0v4egdh8VaoOzNRI0Qu3xl',
#   'uri': 'spotify:track:0v4egdh8VaoOzNRI0Qu3xl',
#   'track_href': 'https://api.spotify.com/v1/tracks/0v4egdh8VaoOzNRI0Qu3xl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0v4egdh8VaoOzNRI0Qu3xl',
#   'duration_ms': 297333,
#   'time_signature': 4},
#  {'danceability': 0.832,
#   'energy': 0.553,
#   'key': 7,
#   'loudness': -13.705,
#   'mode': 1,
#   'speechiness': 0.0487,
#   'acousticness': 0.0422,
#   'instrumentalness': 0.00356,
#   'liveness': 0.249,
#   'valence': 0.89,
#   'tempo': 119.825,
#   'type': 'audio_features',
#   'id': '6Lphpr9Z6H282Sguw0dUWa',
#   'uri': 'spotify:track:6Lphpr9Z6H282Sguw0dUWa',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Lphpr9Z6H282Sguw0dUWa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Lphpr9Z6H282Sguw0dUWa',
#   'duration_ms': 215693,
#   'time_signature': 4},
#  {'danceability': 0.823,
#   'energy': 0.51,
#   'key': 0,
#   'loudness': -11.235,
#   'mode': 1,
#   'speechiness': 0.0352,
#   'acousticness': 0.212,
#   'instrumentalness': 0.806,
#   'liveness': 0.11,
#   'valence': 0.798,
#   'tempo': 114.83,
#   'type': 'audio_features',
#   'id': '2Rr4ZOnKXUrzjhMPkmkRjK',
#   'uri': 'spotify:track:2Rr4ZOnKXUrzjhMPkmkRjK',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Rr4ZOnKXUrzjhMPkmkRjK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Rr4ZOnKXUrzjhMPkmkRjK',
#   'duration_ms': 335067,
#   'time_signature': 4},
#  {'danceability': 0.706,
#   'energy': 0.723,
#   'key': 5,
#   'loudness': -9.235,
#   'mode': 1,
#   'speechiness': 0.0382,
#   'acousticness': 0.0232,
#   'instrumentalness': 0.0441,
#   'liveness': 0.0994,
#   'valence': 0.937,
#   'tempo': 113.121,
#   'type': 'audio_features',
#   'id': '6HZKlK1mDDBsILMoNNncxL',
#   'uri': 'spotify:track:6HZKlK1mDDBsILMoNNncxL',
#   'track_href': 'https://api.spotify.com/v1/tracks/6HZKlK1mDDBsILMoNNncxL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6HZKlK1mDDBsILMoNNncxL',
#   'duration_ms': 415467,
#   'time_signature': 4},
#  {'danceability': 0.87,
#   'energy': 0.657,
#   'key': 2,
#   'loudness': -7.32,
#   'mode': 1,
#   'speechiness': 0.0522,
#   'acousticness': 0.149,
#   'instrumentalness': 0.0102,
#   'liveness': 0.053,
#   'valence': 0.893,
#   'tempo': 110.596,
#   'type': 'audio_features',
#   'id': '0G3fbPbE1vGeABDEZF0jeG',
#   'uri': 'spotify:track:0G3fbPbE1vGeABDEZF0jeG',
#   'track_href': 'https://api.spotify.com/v1/tracks/0G3fbPbE1vGeABDEZF0jeG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0G3fbPbE1vGeABDEZF0jeG',
#   'duration_ms': 495400,
#   'time_signature': 4},
#  {'danceability': 0.693,
#   'energy': 0.918,
#   'key': 11,
#   'loudness': -6.429,
#   'mode': 0,
#   'speechiness': 0.0632,
#   'acousticness': 0.225,
#   'instrumentalness': 0.00106,
#   'liveness': 0.0547,
#   'valence': 0.765,
#   'tempo': 111.128,
#   'type': 'audio_features',
#   'id': '3gZs2MpDVNJb0CnPwkU3m9',
#   'uri': 'spotify:track:3gZs2MpDVNJb0CnPwkU3m9',
#   'track_href': 'https://api.spotify.com/v1/tracks/3gZs2MpDVNJb0CnPwkU3m9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3gZs2MpDVNJb0CnPwkU3m9',
#   'duration_ms': 259587,
#   'time_signature': 4},
#  {'danceability': 0.887,
#   'energy': 0.904,
#   'key': 5,
#   'loudness': -5.107,
#   'mode': 0,
#   'speechiness': 0.0703,
#   'acousticness': 0.079,
#   'instrumentalness': 0.0101,
#   'liveness': 0.0165,
#   'valence': 0.89,
#   'tempo': 107.955,
#   'type': 'audio_features',
#   'id': '57Y3UccJEJqT8w8RWkUAz0',
#   'uri': 'spotify:track:57Y3UccJEJqT8w8RWkUAz0',
#   'track_href': 'https://api.spotify.com/v1/tracks/57Y3UccJEJqT8w8RWkUAz0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57Y3UccJEJqT8w8RWkUAz0',
#   'duration_ms': 244827,
#   'time_signature': 4},
#  {'danceability': 0.784,
#   'energy': 0.893,
#   'key': 7,
#   'loudness': -5.153,
#   'mode': 0,
#   'speechiness': 0.0923,
#   'acousticness': 0.3,
#   'instrumentalness': 1.57e-05,
#   'liveness': 0.272,
#   'valence': 0.819,
#   'tempo': 118.738,
#   'type': 'audio_features',
#   'id': '5IKLwqBQG6KU6MP2zP80Nu',
#   'uri': 'spotify:track:5IKLwqBQG6KU6MP2zP80Nu',
#   'track_href': 'https://api.spotify.com/v1/tracks/5IKLwqBQG6KU6MP2zP80Nu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IKLwqBQG6KU6MP2zP80Nu',
#   'duration_ms': 216733,
#   'time_signature': 4},
#  {'danceability': 0.758,
#   'energy': 0.841,
#   'key': 0,
#   'loudness': -7.509,
#   'mode': 1,
#   'speechiness': 0.0319,
#   'acousticness': 0.0544,
#   'instrumentalness': 0.000153,
#   'liveness': 0.103,
#   'valence': 0.849,
#   'tempo': 114.487,
#   'type': 'audio_features',
#   'id': '7zpm7lTY2EZn7AfFm3mGg2',
#   'uri': 'spotify:track:7zpm7lTY2EZn7AfFm3mGg2',
#   'track_href': 'https://api.spotify.com/v1/tracks/7zpm7lTY2EZn7AfFm3mGg2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7zpm7lTY2EZn7AfFm3mGg2',
#   'duration_ms': 287440,
#   'time_signature': 4},
#  {'danceability': 0.72,
#   'energy': 0.856,
#   'key': 2,
#   'loudness': -8.74,
#   'mode': 0,
#   'speechiness': 0.0448,
#   'acousticness': 0.0122,
#   'instrumentalness': 3.2e-05,
#   'liveness': 0.0667,
#   'valence': 0.891,
#   'tempo': 113.871,
#   'type': 'audio_features',
#   'id': '10SfRsGOylSFoJEmGWeM1Q',
#   'uri': 'spotify:track:10SfRsGOylSFoJEmGWeM1Q',
#   'track_href': 'https://api.spotify.com/v1/tracks/10SfRsGOylSFoJEmGWeM1Q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/10SfRsGOylSFoJEmGWeM1Q',
#   'duration_ms': 214867,
#   'time_signature': 4},
#  {'danceability': 0.833,
#   'energy': 0.728,
#   'key': 8,
#   'loudness': -9.369,
#   'mode': 0,
#   'speechiness': 0.0478,
#   'acousticness': 0.411,
#   'instrumentalness': 0.0349,
#   'liveness': 0.131,
#   'valence': 0.944,
#   'tempo': 113.735,
#   'type': 'audio_features',
#   'id': '56OCQ7KmuqNqjI1DH9rjHV',
#   'uri': 'spotify:track:56OCQ7KmuqNqjI1DH9rjHV',
#   'track_href': 'https://api.spotify.com/v1/tracks/56OCQ7KmuqNqjI1DH9rjHV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56OCQ7KmuqNqjI1DH9rjHV',
#   'duration_ms': 209733,
#   'time_signature': 4},
#  {'danceability': 0.761,
#   'energy': 0.894,
#   'key': 1,
#   'loudness': -5.671,
#   'mode': 1,
#   'speechiness': 0.0794,
#   'acousticness': 0.0136,
#   'instrumentalness': 0.0258,
#   'liveness': 0.331,
#   'valence': 0.872,
#   'tempo': 123.886,
#   'type': 'audio_features',
#   'id': '3LZRLOdSwmpPk6ZvOW6B4B',
#   'uri': 'spotify:track:3LZRLOdSwmpPk6ZvOW6B4B',
#   'track_href': 'https://api.spotify.com/v1/tracks/3LZRLOdSwmpPk6ZvOW6B4B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3LZRLOdSwmpPk6ZvOW6B4B',
#   'duration_ms': 524627,
#   'time_signature': 4},
#  {'danceability': 0.865,
#   'energy': 0.496,
#   'key': 0,
#   'loudness': -9.674,
#   'mode': 0,
#   'speechiness': 0.0298,
#   'acousticness': 0.0128,
#   'instrumentalness': 0.554,
#   'liveness': 0.0863,
#   'valence': 0.931,
#   'tempo': 99.758,
#   'type': 'audio_features',
#   'id': '6X0WOhuJzhwFzZNjSmtHNn',
#   'uri': 'spotify:track:6X0WOhuJzhwFzZNjSmtHNn',
#   'track_href': 'https://api.spotify.com/v1/tracks/6X0WOhuJzhwFzZNjSmtHNn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6X0WOhuJzhwFzZNjSmtHNn',
#   'duration_ms': 323427,
#   'time_signature': 4},
#  {'danceability': 0.713,
#   'energy': 0.7,
#   'key': 11,
#   'loudness': -7.366,
#   'mode': 0,
#   'speechiness': 0.038,
#   'acousticness': 0.0797,
#   'instrumentalness': 0.000941,
#   'liveness': 0.32,
#   'valence': 0.961,
#   'tempo': 127.593,
#   'type': 'audio_features',
#   'id': '7lR4bm4cQ1c3EHEfhiaBkg',
#   'uri': 'spotify:track:7lR4bm4cQ1c3EHEfhiaBkg',
#   'track_href': 'https://api.spotify.com/v1/tracks/7lR4bm4cQ1c3EHEfhiaBkg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7lR4bm4cQ1c3EHEfhiaBkg',
#   'duration_ms': 296693,
#   'time_signature': 4},
#  {'danceability': 0.897,
#   'energy': 0.577,
#   'key': 11,
#   'loudness': -9.366,
#   'mode': 1,
#   'speechiness': 0.0552,
#   'acousticness': 0.0521,
#   'instrumentalness': 0.000139,
#   'liveness': 0.0671,
#   'valence': 0.875,
#   'tempo': 116.158,
#   'type': 'audio_features',
#   'id': '1yy3w1fvSjxglxfUiG0mE3',
#   'uri': 'spotify:track:1yy3w1fvSjxglxfUiG0mE3',
#   'track_href': 'https://api.spotify.com/v1/tracks/1yy3w1fvSjxglxfUiG0mE3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1yy3w1fvSjxglxfUiG0mE3',
#   'duration_ms': 423360,
#   'time_signature': 4},
#  {'danceability': 0.663,
#   'energy': 0.744,
#   'key': 9,
#   'loudness': -7.365,
#   'mode': 0,
#   'speechiness': 0.049,
#   'acousticness': 0.205,
#   'instrumentalness': 7.57e-06,
#   'liveness': 0.169,
#   'valence': 0.815,
#   'tempo': 119.592,
#   'type': 'audio_features',
#   'id': '0R8Pz445amp2wRMSd1jpql',
#   'uri': 'spotify:track:0R8Pz445amp2wRMSd1jpql',
#   'track_href': 'https://api.spotify.com/v1/tracks/0R8Pz445amp2wRMSd1jpql',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0R8Pz445amp2wRMSd1jpql',
#   'duration_ms': 215293,
#   'time_signature': 4},
#  {'danceability': 0.837,
#   'energy': 0.455,
#   'key': 5,
#   'loudness': -15.326,
#   'mode': 1,
#   'speechiness': 0.0354,
#   'acousticness': 0.0296,
#   'instrumentalness': 0.589,
#   'liveness': 0.0398,
#   'valence': 0.922,
#   'tempo': 114.762,
#   'type': 'audio_features',
#   'id': '6iEFcZI1KxxPaAGlnOVn3y',
#   'uri': 'spotify:track:6iEFcZI1KxxPaAGlnOVn3y',
#   'track_href': 'https://api.spotify.com/v1/tracks/6iEFcZI1KxxPaAGlnOVn3y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6iEFcZI1KxxPaAGlnOVn3y',
#   'duration_ms': 307293,
#   'time_signature': 4},
#  {'danceability': 0.651,
#   'energy': 0.748,
#   'key': 4,
#   'loudness': -12.541,
#   'mode': 0,
#   'speechiness': 0.0673,
#   'acousticness': 0.219,
#   'instrumentalness': 0,
#   'liveness': 0.0874,
#   'valence': 0.931,
#   'tempo': 102.353,
#   'type': 'audio_features',
#   'id': '550WUwe2By7lQYiF5Tnp4U',
#   'uri': 'spotify:track:550WUwe2By7lQYiF5Tnp4U',
#   'track_href': 'https://api.spotify.com/v1/tracks/550WUwe2By7lQYiF5Tnp4U',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/550WUwe2By7lQYiF5Tnp4U',
#   'duration_ms': 212053,
#   'time_signature': 4},
#  {'danceability': 0.758,
#   'energy': 0.723,
#   'key': 0,
#   'loudness': -8.603,
#   'mode': 1,
#   'speechiness': 0.0826,
#   'acousticness': 0.367,
#   'instrumentalness': 0,
#   'liveness': 0.118,
#   'valence': 0.898,
#   'tempo': 116.662,
#   'type': 'audio_features',
#   'id': '7Bfe5F9CqsdZlP2lqvra0m',
#   'uri': 'spotify:track:7Bfe5F9CqsdZlP2lqvra0m',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Bfe5F9CqsdZlP2lqvra0m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Bfe5F9CqsdZlP2lqvra0m',
#   'duration_ms': 260880,
#   'time_signature': 4}]

# %% [markdown]
# ### Getting them in chunks of 50  and assigning into a DataFrame

# %%
# songs: a list of song ids

def chunks(lst, n):
    #"""Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

        
audio_feats = []
for chunk in list(chunks(soultrain_1, 50)):
        audio_feats.append(sp.audio_features(chunk))
        
audio_feats_new = [feats for subfeats in audio_feats for feats in subfeats]

# %%
len(audio_feats_new)
# Out:
# 875

# %%
# creating df
soultrain_df = pd.DataFrame(audio_feats_new)

# %%
# checking it's shape 
soultrain_df.shape
# Out:
# (875, 18)

# %%
# checking df
soultrain_df.head(10)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.673    7   -10.211     0       0.0299       0.12700
# 1         0.869   0.648   11    -8.698     0       0.0633       0.12100
# 2         0.802   0.756    2   -10.791     0       0.0349       0.08430
# 3         0.611   0.899    2   -10.897     1       0.0320       0.01410
# 4         0.817   0.754   11    -8.347     1       0.0467       0.17400
# 5         0.718   0.676   11   -11.633     0       0.0318       0.15300
# 6         0.667   0.577   11   -12.729     1       0.1630       0.22800
# 7         0.673   0.752    9    -7.978     0       0.0491       0.00309
# 8         0.774   0.641    1   -10.193     1       0.0799       0.07650
# 9         0.879   0.626    7    -6.344     1       0.0604       0.20500
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000681    0.1290    0.967  112.669  audio_features
# 1          0.000022    0.1260    0.900  125.035  audio_features
# 2          0.007650    0.0521    0.963  131.715  audio_features
# 3          0.096600    0.0786    0.847  100.868  audio_features
# 4          0.013800    0.0597    0.924   98.182  audio_features
# 5          0.030600    0.0706    0.944  112.711  audio_features
# 6          0.000039    0.0566    0.923  111.802  audio_features
# 7          0.000000    0.1120    0.576  120.041  audio_features
# 8          0.000000    0.0867    0.875  113.256  audio_features
# 9          0.000061    0.0560    0.968  110.864  audio_features
#
#                        id                                   uri  \
# 0  2wNKo4dQkKV06ebyb34Ffb  spotify:track:2wNKo4dQkKV06ebyb34Ffb
# 1  3koCCeSaVUyrRo3N2gHrd8  spotify:track:3koCCeSaVUyrRo3N2gHrd8
# 2  6ztstiyZL6FXzh4aG46ZPD  spotify:track:6ztstiyZL6FXzh4aG46ZPD
# 3  60z6SdowBWlN6n8U0O2NP8  spotify:track:60z6SdowBWlN6n8U0O2NP8
# 4  2rZFZPfEf54mWk2qGkR2SV  spotify:track:2rZFZPfEf54mWk2qGkR2SV
# 5  1uGFGhxJ9ISGcy7iDffP7V  spotify:track:1uGFGhxJ9ISGcy7iDffP7V
# 6  5F8CrWvnESlOBmFkyxFJqt  spotify:track:5F8CrWvnESlOBmFkyxFJqt
# 7  2a1MrtxYybqFV1Ow8VJ1dW  spotify:track:2a1MrtxYybqFV1Ow8VJ1dW
# 8  3qI94hINNNeb4S7xQi18lS  spotify:track:3qI94hINNNeb4S7xQi18lS
# 9  1OsCKwNZxph96EkNusILRy  spotify:track:1OsCKwNZxph96EkNusILRy
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2wNKo4dQkKV0...
# 1  https://api.spotify.com/v1/tracks/3koCCeSaVUyr...
# 2  https://api.spotify.com/v1/tracks/6ztstiyZL6FX...
# 3  https://api.spotify.com/v1/tracks/60z6SdowBWlN...
# 4  https://api.spotify.com/v1/tracks/2rZFZPfEf54m...
# 5  https://api.spotify.com/v1/tracks/1uGFGhxJ9ISG...
# 6  https://api.spotify.com/v1/tracks/5F8CrWvnESlO...
# 7  https://api.spotify.com/v1/tracks/2a1MrtxYybqF...
# 8  https://api.spotify.com/v1/tracks/3qI94hINNNeb...
# 9  https://api.spotify.com/v1/tracks/1OsCKwNZxph9...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2wNK...       260693
# 1  https://api.spotify.com/v1/audio-analysis/3koC...       339320
# 2  https://api.spotify.com/v1/audio-analysis/6zts...       288293
# 3  https://api.spotify.com/v1/audio-analysis/60z6...       549000
# 4  https://api.spotify.com/v1/audio-analysis/2rZF...       244440
# 5  https://api.spotify.com/v1/audio-analysis/1uGF...       316267
# 6  https://api.spotify.com/v1/audio-analysis/5F8C...       209800
# 7  https://api.spotify.com/v1/audio-analysis/2a1M...       265027
# 8  https://api.spotify.com/v1/audio-analysis/3qI9...       214200
# 9  https://api.spotify.com/v1/audio-analysis/1OsC...       212907
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4

# %% [markdown]
# ### Dropping columns, preparing to cluster

# %%
soultrain_df = soultrain_df.drop(['type', 'id', 'uri', 'track_href', 'analysis_url'],  axis=1)

# %%
X = soultrain_df

# %% [markdown]
# ### Applying StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
X_prep = StandardScaler().fit_transform(X)

X_prep_df = pd.DataFrame(X_prep, columns = soultrain_df.columns)

# %% [markdown]
# ### Creating clusters

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=8, random_state=1234)

kmeans.fit(X_prep_df)

kmeans.cluster_centers_
# Out:
# array([[ 6.40225260e-01, -1.19273880e+00, -7.12520431e-02,
#         -1.09286131e+00, -6.23498213e-02, -9.25645957e-02,
#         -3.29743569e-01, -2.07643965e-01, -3.77953057e-01,
#          2.95787844e-01,  2.28327453e-02,  7.29099957e-02,
#          0.00000000e+00],
#        [-2.07170721e-01,  4.88660586e-01, -3.93001333e-01,
#          3.85467506e-01,  9.92031746e-01, -1.72440850e-01,
#         -3.10435369e-01, -2.73722072e-01, -8.04346923e-02,
#         -1.16348340e-01, -4.41311557e-02, -8.45707703e-02,
#          0.00000000e+00],
#        [ 3.82249540e-01, -2.20387520e-01,  2.09480483e-01,
#         -3.46747875e-01,  6.17019745e-01,  3.64789892e+00,
#          1.81342960e-01, -3.79498056e-01, -6.59880086e-02,
#         -1.02665074e+00, -3.52869822e-02, -1.44047054e-01,
#          0.00000000e+00],
#        [-6.51441013e-01,  4.40430780e-01,  2.53404620e-01,
#          2.67639568e-01, -2.02450923e-01,  9.30728853e-02,
#          2.27640559e-01, -2.64557021e-01,  2.28776726e+00,
#         -5.92813599e-01,  6.93417998e-02,  4.42921620e-01,
#          0.00000000e+00],
#        [-1.31168863e-01,  3.80109562e-01,  2.55778897e-01,
#          3.97270105e-01, -1.00803226e+00, -1.96932577e-01,
#         -2.54551812e-01, -3.28572792e-01, -1.87534691e-01,
#          1.62961035e-01,  3.36602526e-02, -1.62462151e-01,
#          0.00000000e+00],
#        [-1.61935350e-01, -1.68742550e-02,  3.78696460e-03,
#         -6.08554716e-02,  2.11518964e-01, -2.70111711e-01,
#         -4.00303475e-01,  2.70146893e+00, -2.96815660e-01,
#         -3.05708547e-01,  4.01492245e-01,  5.14173906e-01,
#          2.55079276e-01],
#        [-5.23868797e-01,  1.26678951e+00, -4.49381568e-01,
#          1.80811432e+00, -1.00803226e+00,  9.42155113e-01,
#          1.45989770e+00, -4.84674662e-01,  5.81725971e-02,
#         -5.18916219e-01,  2.98144676e-03,  2.87477538e-01,
#         -2.09165007e+01],
#        [ 1.76998730e-02,  1.52063250e-01,  1.29766309e-01,
#          3.75573658e-01,  1.77190855e-01, -8.41417213e-02,
#          2.33028050e+00, -2.92295660e-01, -1.35598494e-01,
#          4.18594111e-01, -4.88792724e-01, -3.71366735e-01,
#          0.00000000e+00]])

# %%
# total inertia of all the centroids
kmeans.inertia_
# Out:
# 7393.9628737600615

# %%
clusters = kmeans.predict(X_prep)
clusters
# Out:
# array([4, 4, 4, 1, 7, 4, 2, 4, 1, 7, 0, 4, 0, 0, 7, 7, 4, 4, 4, 4, 4, 1,
#        0, 5, 0, 0, 0, 0, 4, 0, 4, 4, 0, 5, 1, 1, 4, 4, 7, 1, 4, 7, 1, 0,
#        4, 0, 4, 0, 4, 7, 4, 0, 1, 1, 1, 7, 4, 3, 0, 1, 1, 3, 4, 0, 3, 1,
#        4, 1, 4, 4, 0, 7, 4, 1, 7, 1, 1, 1, 7, 5, 3, 0, 4, 4, 0, 0, 1, 7,
#        5, 1, 1, 4, 1, 3, 4, 2, 1, 7, 0, 7, 2, 4, 4, 1, 1, 4, 0, 4, 1, 4,
#        5, 1, 4, 5, 4, 5, 0, 0, 0, 0, 4, 7, 5, 4, 0, 0, 1, 1, 7, 1, 3, 3,
#        1, 0, 4, 5, 4, 1, 4, 1, 1, 0, 1, 4, 0, 1, 0, 0, 5, 0, 4, 0, 0, 3,
#        4, 4, 7, 1, 0, 0, 1, 4, 4, 2, 1, 3, 3, 2, 4, 4, 0, 1, 4, 2, 1, 1,
#        2, 3, 5, 0, 0, 4, 4, 1, 1, 4, 5, 1, 3, 7, 7, 0, 7, 5, 4, 1, 0, 4,
#        7, 5, 4, 1, 4, 4, 7, 0, 2, 4, 4, 4, 1, 4, 0, 2, 4, 7, 7, 4, 1, 1,
#        3, 1, 4, 1, 4, 1, 7, 1, 3, 4, 4, 1, 4, 0, 0, 1, 4, 1, 4, 7, 2, 4,
#        1, 4, 0, 3, 1, 4, 1, 1, 1, 0, 7, 5, 1, 1, 0, 6, 7, 7, 7, 3, 4, 5,
#        4, 7, 0, 3, 1, 3, 2, 4, 4, 4, 0, 1, 4, 1, 1, 0, 0, 1, 0, 5, 0, 0,
#        0, 4, 1, 0, 4, 1, 7, 1, 4, 2, 4, 4, 7, 5, 0, 0, 1, 4, 0, 0, 5, 4,
#        0, 1, 4, 0, 0, 4, 4, 1, 1, 3, 7, 4, 0, 7, 7, 4, 0, 0, 5, 0, 4, 1,
#        4, 0, 4, 4, 4, 0, 1, 1, 3, 1, 5, 1, 4, 0, 4, 4, 2, 2, 0, 0, 4, 4,
#        2, 0, 1, 0, 0, 4, 1, 3, 4, 7, 7, 1, 0, 3, 0, 4, 1, 0, 4, 4, 1, 5,
#        5, 0, 3, 5, 1, 1, 1, 0, 4, 3, 1, 7, 0, 1, 1, 0, 2, 0, 4, 0, 4, 4,
#        0, 5, 4, 1, 4, 7, 1, 5, 7, 4, 3, 3, 1, 4, 3, 4, 4, 1, 7, 7, 0, 1,
#        3, 1, 1, 2, 1, 4, 7, 1, 0, 0, 4, 1, 1, 4, 1, 5, 0, 3, 1, 4, 4, 4,
#        4, 5, 4, 0, 5, 1, 3, 3, 5, 4, 1, 3, 0, 4, 4, 5, 4, 7, 0, 3, 0, 7,
#        3, 4, 0, 4, 7, 1, 1, 1, 0, 4, 5, 5, 4, 4, 0, 0, 4, 4, 7, 1, 4, 3,
#        7, 4, 1, 4, 1, 0, 1, 1, 7, 1, 0, 2, 0, 4, 0, 1, 1, 4, 1, 4, 5, 2,
#        7, 7, 4, 3, 1, 5, 4, 1, 0, 1, 0, 4, 3, 3, 7, 1, 0, 4, 7, 5, 0, 5,
#        0, 4, 3, 1, 0, 3, 4, 1, 4, 5, 1, 4, 3, 4, 0, 3, 4, 0, 5, 3, 5, 0,
#        1, 4, 1, 3, 1, 0, 0, 3, 4, 0, 4, 0, 0, 5, 5, 1, 2, 4, 7, 0, 1, 4,
#        1, 5, 0, 3, 3, 3, 1, 5, 4, 0, 0, 2, 0, 7, 1, 1, 2, 4, 1, 3, 1, 5,
#        5, 7, 3, 1, 1, 0, 2, 4, 0, 0, 1, 4, 0, 1, 1, 5, 1, 1, 7, 0, 0, 0,
#        0, 3, 5, 4, 1, 0, 1, 1, 7, 5, 0, 1, 3, 1, 5, 5, 7, 2, 1, 4, 4, 4,
#        1, 3, 3, 4, 1, 4, 4, 1, 4, 4, 1, 5, 0, 1, 4, 1, 4, 0, 1, 4, 4, 1,
#        1, 4, 0, 0, 1, 1, 0, 7, 1, 0, 7, 3, 1, 7, 4, 4, 4, 0, 1, 1, 5, 1,
#        5, 1, 1, 7, 7, 5, 5, 4, 4, 0, 0, 0, 0, 3, 0, 0, 2, 0, 4, 4, 5, 7,
#        5, 1, 5, 5, 5, 5, 0, 0, 4, 0, 0, 7, 4, 1, 0, 0, 4, 1, 7, 0, 4, 3,
#        1, 4, 4, 7, 4, 3, 3, 3, 4, 0, 0, 1, 2, 7, 0, 3, 0, 0, 1, 4, 4, 7,
#        4, 0, 7, 1, 3, 4, 2, 5, 4, 1, 1, 2, 4, 3, 5, 1, 5, 0, 0, 1, 5, 4,
#        4, 0, 0, 5, 1, 5, 4, 7, 1, 4, 5, 1, 7, 0, 0, 7, 4, 0, 0, 0, 4, 1,
#        5, 1, 5, 4, 5, 1, 0, 0, 4, 7, 4, 4, 1, 5, 1, 0, 1, 1, 0, 1, 0, 0,
#        4, 5, 1, 4, 4, 0, 7, 1, 0, 3, 3, 4, 0, 0, 1, 0, 5, 4, 2, 2, 2, 4,
#        0, 1, 4, 7, 3, 0, 5, 1, 7, 5, 5, 5, 4, 0, 3, 4, 1, 4, 4, 1, 1, 5,
#        3, 3, 1, 3, 3, 4, 0, 2, 3, 5, 5, 1, 7, 4, 1, 4, 7], dtype=int32)

# %%
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    184
# 1    201
# 2     32
# 3     72
# 4    222
# 5     82
# 6      1
# 7     81
# dtype: int64

# %%
kmeans.cluster_centers_
# Out:
# array([[ 6.40225260e-01, -1.19273880e+00, -7.12520431e-02,
#         -1.09286131e+00, -6.23498213e-02, -9.25645957e-02,
#         -3.29743569e-01, -2.07643965e-01, -3.77953057e-01,
#          2.95787844e-01,  2.28327453e-02,  7.29099957e-02,
#          0.00000000e+00],
#        [-2.07170721e-01,  4.88660586e-01, -3.93001333e-01,
#          3.85467506e-01,  9.92031746e-01, -1.72440850e-01,
#         -3.10435369e-01, -2.73722072e-01, -8.04346923e-02,
#         -1.16348340e-01, -4.41311557e-02, -8.45707703e-02,
#          0.00000000e+00],
#        [ 3.82249540e-01, -2.20387520e-01,  2.09480483e-01,
#         -3.46747875e-01,  6.17019745e-01,  3.64789892e+00,
#          1.81342960e-01, -3.79498056e-01, -6.59880086e-02,
#         -1.02665074e+00, -3.52869822e-02, -1.44047054e-01,
#          0.00000000e+00],
#        [-6.51441013e-01,  4.40430780e-01,  2.53404620e-01,
#          2.67639568e-01, -2.02450923e-01,  9.30728853e-02,
#          2.27640559e-01, -2.64557021e-01,  2.28776726e+00,
#         -5.92813599e-01,  6.93417998e-02,  4.42921620e-01,
#          0.00000000e+00],
#        [-1.31168863e-01,  3.80109562e-01,  2.55778897e-01,
#          3.97270105e-01, -1.00803226e+00, -1.96932577e-01,
#         -2.54551812e-01, -3.28572792e-01, -1.87534691e-01,
#          1.62961035e-01,  3.36602526e-02, -1.62462151e-01,
#          0.00000000e+00],
#        [-1.61935350e-01, -1.68742550e-02,  3.78696460e-03,
#         -6.08554716e-02,  2.11518964e-01, -2.70111711e-01,
#         -4.00303475e-01,  2.70146893e+00, -2.96815660e-01,
#         -3.05708547e-01,  4.01492245e-01,  5.14173906e-01,
#          2.55079276e-01],
#        [-5.23868797e-01,  1.26678951e+00, -4.49381568e-01,
#          1.80811432e+00, -1.00803226e+00,  9.42155113e-01,
#          1.45989770e+00, -4.84674662e-01,  5.81725971e-02,
#         -5.18916219e-01,  2.98144676e-03,  2.87477538e-01,
#         -2.09165007e+01],
#        [ 1.76998730e-02,  1.52063250e-01,  1.29766309e-01,
#          3.75573658e-01,  1.77190855e-01, -8.41417213e-02,
#          2.33028050e+00, -2.92295660e-01, -1.35598494e-01,
#          4.18594111e-01, -4.88792724e-01, -3.71366735e-01,
#          0.00000000e+00]])

# %%
X_df = pd.DataFrame(X)
X_df['cluster'] = clusters
X_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.673    7   -10.211     0       0.0299        0.1270
# 1         0.869   0.648   11    -8.698     0       0.0633        0.1210
# 2         0.802   0.756    2   -10.791     0       0.0349        0.0843
# 3         0.611   0.899    2   -10.897     1       0.0320        0.0141
# 4         0.817   0.754   11    -8.347     1       0.0467        0.1740
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.000681    0.1290    0.967  112.669       260693               4
# 1          0.000022    0.1260    0.900  125.035       339320               4
# 2          0.007650    0.0521    0.963  131.715       288293               4
# 3          0.096600    0.0786    0.847  100.868       549000               4
# 4          0.013800    0.0597    0.924   98.182       244440               4
#
#    cluster
# 0        4
# 1        4
# 2        4
# 3        1
# 4        7

# %%
X_df['cluster'].plot(kind='hist');

# %% [markdown]
# ### Adding song names to the DataFrame

# %%
# Function to look up the name and id of each song and create a new dictionary 
# with these two iteams as key and vlaue. 

soultrain_1 = {}
length_of_playlist_items = len(soultrain)
for i in range(length_of_playlist_items):
    a = soultrain[i]['track']['id']
    b = soultrain[i]['track']['name']
    soultrain_1[a] = b

# %%
X_df['id'] = soultrain_df['id']

# %%
X_df["name"] = ""

# %%
X_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.754   0.673    7   -10.211     0       0.0299        0.1270
# 1           0.869   0.648   11    -8.698     0       0.0633        0.1210
# 2           0.802   0.756    2   -10.791     0       0.0349        0.0843
# 3           0.611   0.899    2   -10.897     1       0.0320        0.0141
# 4           0.817   0.754   11    -8.347     1       0.0467        0.1740
# ..            ...     ...  ...       ...   ...          ...           ...
# 870         0.706   0.699    9   -12.629     1       0.1720        0.6080
# 871         0.678   0.850   11    -7.849     0       0.0855        0.1300
# 872         0.720   0.757    0   -10.723     1       0.0627        0.0502
# 873         0.759   0.790    8    -9.005     0       0.1240        0.1000
# 874         0.785   0.615    7   -12.137     1       0.0689        0.4120
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# 0            0.000681    0.1290    0.967  112.669       260693
# 1            0.000022    0.1260    0.900  125.035       339320
# 2            0.007650    0.0521    0.963  131.715       288293
# 3            0.096600    0.0786    0.847  100.868       549000
# 4            0.013800    0.0597    0.924   98.182       244440
# ..                ...       ...      ...      ...          ...
# 870          0.000000    0.0762    0.700   97.993       201747
# 871          0.013100    0.0738    0.426  119.835       226547
# 872          0.002560    0.0666    0.484  118.270       491000
# 873          0.291000    0.0306    0.739  118.583       280000
# 874          0.000166    0.0651    0.862   96.094       498293
#
#      time_signature  cluster                      id name
# 0                 4        4  2wNKo4dQkKV06ebyb34Ffb
# 1                 4        4  3koCCeSaVUyrRo3N2gHrd8
# 2                 4        4  6ztstiyZL6FXzh4aG46ZPD
# 3                 4        1  60z6SdowBWlN6n8U0O2NP8
# 4                 4        7  2rZFZPfEf54mWk2qGkR2SV
# ..              ...      ...                     ...  ...
# 870               4        7  2xHP35CnfAfAyxZLKQZ1XC
# 871               4        4  2wsVvmGSp46TlbTeGt7EGo
# 872               4        1  2j8m9sboX9FFadbKctTXq1
# 873               4        4  51Hi86XvW7X8MoCyhTITtM
# 874               4        7  33zSq2gTrexFo9bloxAG0V
#
# [875 rows x 16 columns]

# %%
# create a column in the dataframe with the song name
for i in range(850):
    X_df['name'][i] = soultrain_1[X_df['id'][i]]
# Out:
# <ipython-input-170-caab64071e8e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_df['name'][i] = soultrain_1[X_df['id'][i]]

# %%
X_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.754   0.673    7   -10.211     0       0.0299        0.1270
# 1           0.869   0.648   11    -8.698     0       0.0633        0.1210
# 2           0.802   0.756    2   -10.791     0       0.0349        0.0843
# 3           0.611   0.899    2   -10.897     1       0.0320        0.0141
# 4           0.817   0.754   11    -8.347     1       0.0467        0.1740
# ..            ...     ...  ...       ...   ...          ...           ...
# 870         0.706   0.699    9   -12.629     1       0.1720        0.6080
# 871         0.678   0.850   11    -7.849     0       0.0855        0.1300
# 872         0.720   0.757    0   -10.723     1       0.0627        0.0502
# 873         0.759   0.790    8    -9.005     0       0.1240        0.1000
# 874         0.785   0.615    7   -12.137     1       0.0689        0.4120
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# 0            0.000681    0.1290    0.967  112.669       260693
# 1            0.000022    0.1260    0.900  125.035       339320
# 2            0.007650    0.0521    0.963  131.715       288293
# 3            0.096600    0.0786    0.847  100.868       549000
# 4            0.013800    0.0597    0.924   98.182       244440
# ..                ...       ...      ...      ...          ...
# 870          0.000000    0.0762    0.700   97.993       201747
# 871          0.013100    0.0738    0.426  119.835       226547
# 872          0.002560    0.0666    0.484  118.270       491000
# 873          0.291000    0.0306    0.739  118.583       280000
# 874          0.000166    0.0651    0.862   96.094       498293
#
#      time_signature  cluster                      id                      name
# 0                 4        4  2wNKo4dQkKV06ebyb34Ffb  I Can Make You Feel Good
# 1                 4        4  3koCCeSaVUyrRo3N2gHrd8              Let's Groove
# 2                 4        4  6ztstiyZL6FXzh4aG46ZPD         Boogie Wonderland
# 3                 4        1  60z6SdowBWlN6n8U0O2NP8        Just Be Good to Me
# 4                 4        7  2rZFZPfEf54mWk2qGkR2SV      Don't Stop The Music
# ..              ...      ...                     ...                       ...
# 870               4        7  2xHP35CnfAfAyxZLKQZ1XC
# 871               4        4  2wsVvmGSp46TlbTeGt7EGo
# 872               4        1  2j8m9sboX9FFadbKctTXq1
# 873               4        4  51Hi86XvW7X8MoCyhTITtM
# 874               4        7  33zSq2gTrexFo9bloxAG0V
#
# [875 rows x 16 columns]

# %% [markdown]
# ### Recommendation function

# %%
def recommender():
    from random import randint
    # input from user
    song_choice=input("What song do you like right now?")
    if len(song_choice)==0:
        print("it looks like you cant think of a song at the moment")
    else: 
        song_choice_l=song_choice.lower() #convert input to lowercase
        filter_song=seventiesfunk[(seventiesfunk["title"].str.lower()).str.contains(song_choice_l)]# convert target to lowercase
        # check if its in the list we have
        if len(filter_song) ==0:
            print("that song is not hot, sorry")

        else:
            # if song is in billboard hot 100, confirm it, recommend another random hot song
            print("That's a hot song.")
            random_song = randint(0, len(top_100)-1)
            print("You might also like " + top_100["title"][random_song] + " by " + top_100["performed_by"][random_song])
